# %% [markdown]
# ## An Implementation of Djikstra's Algorithm to a League of Legends Champion
#
# The aim of the project is to develop a full set of solutions to the Aphelios's rotating weapon system problem. In the end, we will create a table where each weapon state (row index) is paired to each other weapon state AND weapon cycle (column index). The only necessary input will be the network edge list, created separately (see ['Aphelios Network Define.xlsx'](https://github.com/paulsylvia20/Djikstras_Algorithm/blob/main/Aphelios%20Network%20Define.xlsx)). I will assume some basic familiarity with [edge lists](https://www.youtube.com/watch?v=83RbL8n3vYU), however, there are plenty of resources online for those who are unfamiliar.
#
# The path finding function maintains three running lists. First, it keeps a tally (dictionary) of all nodes that have been visited so far (visited_nodes). This ensures that when a node and its shortest path are found, the node is never revisited by longer paths. Second, the function maintains a priority list where current paths and their lengths are stored, sorted by length, then expanded to their adjacent nodes (paths). Third is the solutions list where shortest path(s) to a target node along with its length is stored when discovered. This is the final output of the algorithm (solutions).
#
# The original Djikstra's algorithm is capable of finding every shortest path from a start node to every other node in the network. However, to keep the code concise, I will run Djikstra's algorithm once for each start-node -> target-node pairing. Future versions might optimize the algorithm by storing all shortest paths to each other node in the network, given a particular start-node, in a single pass.

# %%
import os
import pandas as pd

os.chdir("C:/Users/pauls/Desktop/Portfolio/Dijkstra's Algorithm")
edges = pd.read_excel("Aphelios Network Define.xlsx", sheet_name="Complete Network") #dataframe: [[source, target, length],] <- str, str, int

print(edges)
# Out:
#     Source Target  Length                  Label
# 0      WRG    RGP       1           Base Network
# 1      PRG    RGW       1           Base Network
# 2      BRG    RGW       1           Base Network
# 3      RWG    WGP       1           Base Network
# 4      PWG    WGR       1           Base Network
# ..     ...    ...     ...                    ...
# 235    PBG  GWRPB       0  Associational Network
# 236    PBR  GWPBR       0  Associational Network
# 237    PBW  GPBWR       0  Associational Network
# 238    WBP  GRWBP       0  Associational Network
# 239    WPB  GWPBR       0  Associational Network
#
# [240 rows x 4 columns]

# %% [markdown]
# #### Forward Stepping Function Inner
# This script is layed out like a Russian nesting doll, from the innermost to outerpost part of Djikstra's algorithm. The innermost function, find_next_steps(), takes a path and spits out a list of all edges that would extend the path one step forward. It does this by opening the edges list and finding any of the edges that have the last node in the provided path as a 'Source' node. It eventally returns the edge list, but not before addressing 2 caveats.
#
# *Caveat 1* <br>
# An important element of Djikstra's algorithm is that any nodes stepped-into this way must be marked 'visited.' We accomplish this directly inside of find_next_steps() by examining the output before returning, checking if the "Target" to any of the edges are in visited_nodes, removing them if they have, and marking them in visited_nodes if they haven't. We do this because the basic logic ensures that any visited nodes already have a shortest path. Thus, any future attempts to visit this node must involve longer or equal length paths.
#
# *Caveat 2* <br>
# In the standard algorithm, we would apply this logic by (a) checking whether a "Target" node is a member of visited_nodes and, if so, (b) preventing it from ever being visited again. However, the standard algorithm guarantees that we output exactly *one* shortest path for each start_node -> end_node pairing. But we would like to store *all* shortest paths, even if there are two or three of them (i.e., two paths going from start_node to end_node that are equal length). To accomplish this, we instruct the find_next_steps() function to only drop a path if it is in the visited_nodes dictionary AND the current path is longer than the known shortest distance to the start_node. Otherwise, the algorithm proceeds with all equivalent paths traveling together towards end_node. In the end, we will store all equivalent paths as solutions.

# %%
# Relevant input data structures
paths = [] # [[length, ['list of nodes']], ...]
visited_nodes = {} # "Node index": shortest dx from start, ...}

# Define a function that takes previous path as input
# Maps out the next steps while updating visited_nodes
def find_next_steps(path, visited_nodes):
    last_node = path[1][-1] # Takes the last node in the current path taken
    
    # Next we generate the next steps. We produce a list from the original edge list wherever the last_node was "Source".
    next_steps = edges[edges["Source"].str.contains(last_node)] #A pandas dataframe similar to the original edge list.

    # Complex Updating of Visited and Next Nodes
    for index, i in next_steps.iterrows(): # Iterate through the next_steps (row entries)
        new_path_length = path[0] + i["Length"] # Determine the new path length by adding edge length to the old path length.
        if i["Target"] in visited_nodes.keys() and new_path_length > visited_nodes[i["Target"]]: #Check whether the new length is equivalent if already visited
            next_steps = next_steps.drop(index) # Drop if longer

        elif i["Target"] not in visited_nodes.keys(): # Add to visited if not visited before
            visited_nodes[i["Target"]] = new_path_length

    return next_steps, visited_nodes

# %% [markdown]
# #### Forward Stepping Function Outer
# We've implemented the basic process that needs to be conducted in order to properly find next steps along paths and avoid revisiting nodes. Now we have to ensure the steps are developed using the correct paths at the correct times. The aim of paths_one_step_forward() is to simply progress the paths by (a) finding and pulling the shortest running path in paths, (b) stepping it forward along all of its possible edges while marking visited nodes, and (c) replacing it in the queue with all of the new paths. This is the central iteration underlying Djikstra's algorithm:

# %%
paths = [] # [[length, ['list of nodes']], ... ]
visited_nodes = {} # {"Node index": shortest dx from start, ...}

def paths_one_step_forward(paths, visited_nodes):
    import heapq

    path = heapq.heappop(paths) # Pull the shortest running path, removing it from the priority list

    next_steps, visited_nodes = find_next_steps(path, visited_nodes) # Identify the next steps and update the visited_nodes list

    # For each next step, add it to the heap
    for ind, j in next_steps.iterrows(): # Find the new full paths and lengths
        new_path = path[1] + [j["Target"]] # <- full path
        new_length = path[0] + j["Length"] # <- int
        heapq.heappush(paths, [new_length, new_path]) # Append new

    return paths, visited_nodes

# %% [markdown]
# ### Final Implementation
#
# The algorithm is already almost entirely specified. We now just loop paths_one_step forward(). It will progress the search until it satisfies the condition of the loop while handling all necessary management of paths and visited_nodes lists. Since we are less concerned about optimization in this implementation, we will use a while-loop that performs a complete search of the network. At each iteration, we also check paths for solutions. If there is a solution, we store it in solutions, returned at the end. If there are multiple solutions, they will be concatenated into a list.
#
# Note, we have also added the nodes() utility function to enable a simple summarization of the edges list into a complete list of all network nodes.

# %%
class Network():
    def __init__(self, edge_list):
        # Here we've specified that the network class takes an edge_list as input which is common convention in network science.
        # Future work can expand the number of data structures taken.
        self.edges = edge_list
    
    # Finally we implement Djikstra's algorithm:
    def path_find(self, start_node, target): #(self, string, string)
        # We start the essential data structures empty, exept for paths which needs to nucleate 
        # with the starting node in place
        visited_nodes = {} #{"Node index": shortest dx from start, ...}
        paths = [[0,[start_node]]] #[[length, ['list of nodes']], ... ]
        solutions = [] #[[length, ['list of nodes']], ... ]; usually 1 or 2 solutions, sometimes 3

        # The while loop conducts the algorithm, iterating paths_one_step_forward()
        # We could conduct the search using one line, but we also have to extract solutions. Hence, the for-loops to follow.
        while len(paths) > 0:
          paths, visited_nodes = paths_one_step_forward(paths, visited_nodes) #steps the algorithm
          
          # Here we extract solutions.
          # The if condition generates a list of the last node in each path, then checks if it is the target
          if target in [paths[index][1][-1] for index, i in enumerate(paths)]: # If there is a solution in paths.
              
              # The list comprehension pulls the paths that end in the target node
              # In other words the for loop loops through the solutions in paths
              for solution in [i for index, i in enumerate(paths) if paths[index][1][-1] == target]:

                # Here we remove the source node from the beginning of solutions.
                # It was important to "nucleate" them, but is unnecessary for the final solution.
                solution = [solution[0], solution[1][1:len(solution[1])]] 
                if solution not in solutions: # Prevents appending any duplicates.
                  solutions.append(solution)
        
        return solutions
    
    # Here we define a function that consolidates nodes into a single list with the associated labels while erasing edges.
    # Labels are helpful to our use case because they can be used to separate nodes by the networks they are members of.
    def nodes(self): 
        import pandas as pd

        # First we erase Source/Target information (since we are erasing edges),
        # and retain a messy "Node" list with duplicates and labels intact.
        temp = pd.concat((edges[["Source", "Label"]].rename(columns={"Source":"Node"}), 
          edges[["Target", "Label"]].rename(columns={"Target":"Node"})))
        
        # Next we leverage groupby() to clean the messy list,
        # creating a list of all of the unique nodes with all labels preserved together as a list.
        nodes = temp.groupby("Node")["Label"].unique()

        return nodes

# %% [markdown]
# #### Application
# Finally, we apply the algorithm, finding all shortest paths in the network. We avoid starting searches with any of the associational nodes, these are just end points. Instead, we have the 'Base Network' as row indeces and use only these nodes as start points. Then we search from these nodes towards every other node.

# %%
aphelios = Network(edges) # Initiate the class instance for the Aphelios project.
nodes = aphelios.nodes() # Extract the whole network as a list of nodes

print(nodes)
# Out:
# Node
# BGP    [Base Network, Associational Network]
# BGR    [Base Network, Associational Network]
# BGW    [Base Network, Associational Network]
# BPG    [Base Network, Associational Network]
# BPR    [Base Network, Associational Network]
#                        ...
# WPG    [Base Network, Associational Network]
# WPR    [Base Network, Associational Network]
# WRB    [Base Network, Associational Network]
# WRG    [Base Network, Associational Network]
# WRP    [Base Network, Associational Network]
# Name: Label, Length: 84, dtype: object

# %%
# Here we pull a list of nodes that are only part of the base network 
BaseNetwork = [nodes.index[index] for index, i in enumerate(nodes) if "Base Network" in i]
WholeNetwork = nodes.index #and just the whole network

# Here we create a df for the output where the base network is inputs, and whole network is outputs
solutions = pd.DataFrame(data = None,
                         index = BaseNetwork, #inputs
                         columns = WholeNetwork) #outputs

# %%
# Since path_finder() returns one solution at time, we iterate through the df one cell at a time.
# To save on computation, we also include a skip for the main diagonal, where the row/column indexes refer to the 
#   same node and no search should be conducted.

for i in range(solutions.shape[0]): # iterate through rows
   for j in range(solutions.shape[1]): # iterate through columns
        if(solutions.index[i] == solutions.columns[j]): # check if the start_node *is* the end_node (along the main diagonal)
            solutions.iloc[i,j] = "" # impute non-value instead
        else:
            solution = aphelios.path_find(solutions.index[i], solutions.columns[j]) # find the shortest paths
            solutions.iloc[i,j] = solution # store the solution

# %% [markdown]
# #### Final Output

# %%
print(solutions)
solutions.to_csv("Aphelios_Paths.csv")
# Out:
#                                                    BGP  \
# BGP                                                NaN
# BGR                [[4, ['GRW', 'RWB', 'WBG', 'BGP']]]
# BGW                [[4, ['GWR', 'WRB', 'RBG', 'BGP']]]
# BPG  [[5, ['PGR', 'GRW', 'RWB', 'WBG', 'BGP']], [5,...
# BPR                [[4, ['PRW', 'RWB', 'WBG', 'BGP']]]
# BPW                [[4, ['PWR', 'WRB', 'RBG', 'BGP']]]
# BRG         [[5, ['RGP', 'GPW', 'PWB', 'WBG', 'BGP']]]
# BRP                [[4, ['RPW', 'PWB', 'WBG', 'BGP']]]
# BRW  [[6, ['RWG', 'WGP', 'GPR', 'PRB', 'RBG', 'BGP']]]
# BWG         [[5, ['WGP', 'GPR', 'PRB', 'RBG', 'BGP']]]
# BWP                [[4, ['WPR', 'PRB', 'RBG', 'BGP']]]
# BWR  [[6, ['WRG', 'RGP', 'GPW', 'PWB', 'WBG', 'BGP']]]
# GBP  [[5, ['BPR', 'PRW', 'RWB', 'WBG', 'BGP']], [5,...
# GBR         [[5, ['BRP', 'RPW', 'PWB', 'WBG', 'BGP']]]
# GBW         [[5, ['BWP', 'WPR', 'PRB', 'RBG', 'BGP']]]
# GPB  [[7, ['PBR', 'BRG', 'RGP', 'GPW', 'PWB', 'WBG'...
# GPR                       [[3, ['PRB', 'RBG', 'BGP']]]
# GPW                       [[3, ['PWB', 'WBG', 'BGP']]]
# GRB  [[6, ['RBP', 'BPW', 'PWR', 'WRB', 'RBG', 'BGP'...
# GRP                [[4, ['RPW', 'PWB', 'WBG', 'BGP']]]
# GRW                       [[3, ['RWB', 'WBG', 'BGP']]]
# GWB  [[6, ['WBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGP'...
# GWP                [[4, ['WPR', 'PRB', 'RBG', 'BGP']]]
# GWR                       [[3, ['WRB', 'RBG', 'BGP']]]
# PBG  [[5, ['BGR', 'GRW', 'RWB', 'WBG', 'BGP']], [5,...
# PBR  [[6, ['BRG', 'RGP', 'GPW', 'PWB', 'WBG', 'BGP']]]
# PBW  [[6, ['BWG', 'WGP', 'GPR', 'PRB', 'RBG', 'BGP']]]
# PGB  [[6, ['GBR', 'BRP', 'RPW', 'PWB', 'WBG', 'BGP'...
# PGR                [[4, ['GRW', 'RWB', 'WBG', 'BGP']]]
# PGW                [[4, ['GWR', 'WRB', 'RBG', 'BGP']]]
# PRB                              [[2, ['RBG', 'BGP']]]
# PRG  [[6, ['RGW', 'GWP', 'WPR', 'PRB', 'RBG', 'BGP']]]
# PRW                       [[3, ['RWB', 'WBG', 'BGP']]]
# PWB                              [[2, ['WBG', 'BGP']]]
# PWG  [[6, ['WGR', 'GRP', 'RPW', 'PWB', 'WBG', 'BGP']]]
# PWR                       [[3, ['WRB', 'RBG', 'BGP']]]
# RBG                                     [[1, ['BGP']]]
# RBP         [[5, ['BPW', 'PWR', 'WRB', 'RBG', 'BGP']]]
# RBW         [[5, ['BWP', 'WPR', 'PRB', 'RBG', 'BGP']]]
# RGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGP'...
# RGP                [[4, ['GPW', 'PWB', 'WBG', 'BGP']]]
# RGW         [[5, ['GWP', 'WPR', 'PRB', 'RBG', 'BGP']]]
# RPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBG', 'BGP'...
# RPG         [[5, ['PGW', 'GWR', 'WRB', 'RBG', 'BGP']]]
# RPW                       [[3, ['PWB', 'WBG', 'BGP']]]
# RWB                              [[2, ['WBG', 'BGP']]]
# RWG         [[5, ['WGP', 'GPR', 'PRB', 'RBG', 'BGP']]]
# RWP  [[6, ['WPG', 'PGR', 'GRW', 'RWB', 'WBG', 'BGP']]]
# WBG                                     [[1, ['BGP']]]
# WBP         [[5, ['BPR', 'PRW', 'RWB', 'WBG', 'BGP']]]
# WBR         [[5, ['BRP', 'RPW', 'PWB', 'WBG', 'BGP']]]
# WGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGP'...
# WGP                [[4, ['GPR', 'PRB', 'RBG', 'BGP']]]
# WGR         [[5, ['GRP', 'RPW', 'PWB', 'WBG', 'BGP']]]
# WPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBG', 'BGP'...
# WPG         [[5, ['PGR', 'GRW', 'RWB', 'WBG', 'BGP']]]
# WPR                       [[3, ['PRB', 'RBG', 'BGP']]]
# WRB                              [[2, ['RBG', 'BGP']]]
# WRG         [[5, ['RGP', 'GPW', 'PWB', 'WBG', 'BGP']]]
# WRP  [[6, ['RPG', 'PGW', 'GWR', 'WRB', 'RBG', 'BGP']]]
#
#                                                    BGR  \
# BGP                [[4, ['GPW', 'PWB', 'WBG', 'BGR']]]
# BGR                                                NaN
# BGW                [[4, ['GWP', 'WPB', 'PBG', 'BGR']]]
# BPG         [[5, ['PGR', 'GRW', 'RWB', 'WBG', 'BGR']]]
# BPR                [[4, ['PRW', 'RWB', 'WBG', 'BGR']]]
# BPW  [[6, ['PWG', 'WGR', 'GRP', 'RPB', 'PBG', 'BGR']]]
# BRG  [[5, ['RGP', 'GPW', 'PWB', 'WBG', 'BGR']], [5,...
# BRP                [[4, ['RPW', 'PWB', 'WBG', 'BGR']]]
# BRW                [[4, ['RWP', 'WPB', 'PBG', 'BGR']]]
# BWG         [[5, ['WGR', 'GRP', 'RPB', 'PBG', 'BGR']]]
# BWP  [[6, ['WPG', 'PGR', 'GRW', 'RWB', 'WBG', 'BGR']]]
# BWR                [[4, ['WRP', 'RPB', 'PBG', 'BGR']]]
# GBP         [[5, ['BPR', 'PRW', 'RWB', 'WBG', 'BGR']]]
# GBR  [[5, ['BRP', 'RPW', 'PWB', 'WBG', 'BGR']], [5,...
# GBW         [[5, ['BWR', 'WRP', 'RPB', 'PBG', 'BGR']]]
# GPB  [[6, ['PBR', 'BRW', 'RWP', 'WPB', 'PBG', 'BGR'...
# GPR                [[4, ['PRW', 'RWB', 'WBG', 'BGR']]]
# GPW                       [[3, ['PWB', 'WBG', 'BGR']]]
# GRB  [[7, ['RBP', 'BPG', 'PGR', 'GRW', 'RWB', 'WBG'...
# GRP                       [[3, ['RPB', 'PBG', 'BGR']]]
# GRW                       [[3, ['RWB', 'WBG', 'BGR']]]
# GWB  [[6, ['WBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGR'...
# GWP                       [[3, ['WPB', 'PBG', 'BGR']]]
# GWR                [[4, ['WRP', 'RPB', 'PBG', 'BGR']]]
# PBG                                     [[1, ['BGR']]]
# PBR         [[5, ['BRW', 'RWP', 'WPB', 'PBG', 'BGR']]]
# PBW         [[5, ['BWR', 'WRP', 'RPB', 'PBG', 'BGR']]]
# PGB  [[6, ['GBR', 'BRP', 'RPW', 'PWB', 'WBG', 'BGR'...
# PGR                [[4, ['GRW', 'RWB', 'WBG', 'BGR']]]
# PGW         [[5, ['GWR', 'WRP', 'RPB', 'PBG', 'BGR']]]
# PRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBG', 'BGR'...
# PRG         [[5, ['RGW', 'GWP', 'WPB', 'PBG', 'BGR']]]
# PRW                       [[3, ['RWB', 'WBG', 'BGR']]]
# PWB                              [[2, ['WBG', 'BGR']]]
# PWG         [[5, ['WGR', 'GRP', 'RPB', 'PBG', 'BGR']]]
# PWR  [[6, ['WRG', 'RGP', 'GPW', 'PWB', 'WBG', 'BGR']]]
# RBG  [[5, ['BGP', 'GPW', 'PWB', 'WBG', 'BGR']], [5,...
# RBP  [[6, ['BPG', 'PGR', 'GRW', 'RWB', 'WBG', 'BGR']]]
# RBW  [[6, ['BWG', 'WGR', 'GRP', 'RPB', 'PBG', 'BGR']]]
# RGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGR'...
# RGP                [[4, ['GPW', 'PWB', 'WBG', 'BGR']]]
# RGW                [[4, ['GWP', 'WPB', 'PBG', 'BGR']]]
# RPB                              [[2, ['PBG', 'BGR']]]
# RPG  [[6, ['PGW', 'GWR', 'WRP', 'RPB', 'PBG', 'BGR']]]
# RPW                       [[3, ['PWB', 'WBG', 'BGR']]]
# RWB                              [[2, ['WBG', 'BGR']]]
# RWG  [[6, ['WGP', 'GPR', 'PRW', 'RWB', 'WBG', 'BGR']]]
# RWP                       [[3, ['WPB', 'PBG', 'BGR']]]
# WBG                                     [[1, ['BGR']]]
# WBP         [[5, ['BPR', 'PRW', 'RWB', 'WBG', 'BGR']]]
# WBR         [[5, ['BRP', 'RPW', 'PWB', 'WBG', 'BGR']]]
# WGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBG', 'BGR'...
# WGP         [[5, ['GPR', 'PRW', 'RWB', 'WBG', 'BGR']]]
# WGR                [[4, ['GRP', 'RPB', 'PBG', 'BGR']]]
# WPB                              [[2, ['PBG', 'BGR']]]
# WPG         [[5, ['PGR', 'GRW', 'RWB', 'WBG', 'BGR']]]
# WPR  [[6, ['PRG', 'RGW', 'GWP', 'WPB', 'PBG', 'BGR']]]
# WRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBG', 'BGR'...
# WRG         [[5, ['RGP', 'GPW', 'PWB', 'WBG', 'BGR']]]
# WRP                       [[3, ['RPB', 'PBG', 'BGR']]]
#
#                                                    BGW  \
# BGP                [[4, ['GPR', 'PRB', 'RBG', 'BGW']]]
# BGR                [[4, ['GRP', 'RPB', 'PBG', 'BGW']]]
# BGW                                                NaN
# BPG         [[5, ['PGW', 'GWR', 'WRB', 'RBG', 'BGW']]]
# BPR  [[6, ['PRG', 'RGW', 'GWP', 'WPB', 'PBG', 'BGW']]]
# BPW                [[4, ['PWR', 'WRB', 'RBG', 'BGW']]]
# BRG         [[5, ['RGW', 'GWP', 'WPB', 'PBG', 'BGW']]]
# BRP  [[6, ['RPG', 'PGW', 'GWR', 'WRB', 'RBG', 'BGW']]]
# BRW                [[4, ['RWP', 'WPB', 'PBG', 'BGW']]]
# BWG  [[5, ['WGP', 'GPR', 'PRB', 'RBG', 'BGW']], [5,...
# BWP                [[4, ['WPR', 'PRB', 'RBG', 'BGW']]]
# BWR                [[4, ['WRP', 'RPB', 'PBG', 'BGW']]]
# GBP         [[5, ['BPW', 'PWR', 'WRB', 'RBG', 'BGW']]]
# GBR         [[5, ['BRW', 'RWP', 'WPB', 'PBG', 'BGW']]]
# GBW  [[5, ['BWP', 'WPR', 'PRB', 'RBG', 'BGW']], [5,...
# GPB  [[6, ['PBR', 'BRW', 'RWP', 'WPB', 'PBG', 'BGW'...
# GPR                       [[3, ['PRB', 'RBG', 'BGW']]]
# GPW                [[4, ['PWR', 'WRB', 'RBG', 'BGW']]]
# GRB  [[6, ['RBP', 'BPW', 'PWR', 'WRB', 'RBG', 'BGW'...
# GRP                       [[3, ['RPB', 'PBG', 'BGW']]]
# GRW                [[4, ['RWP', 'WPB', 'PBG', 'BGW']]]
# GWB  [[7, ['WBP', 'BPG', 'PGW', 'GWR', 'WRB', 'RBG'...
# GWP                       [[3, ['WPB', 'PBG', 'BGW']]]
# GWR                       [[3, ['WRB', 'RBG', 'BGW']]]
# PBG                                     [[1, ['BGW']]]
# PBR         [[5, ['BRW', 'RWP', 'WPB', 'PBG', 'BGW']]]
# PBW         [[5, ['BWR', 'WRP', 'RPB', 'PBG', 'BGW']]]
# PGB  [[6, ['GBR', 'BRW', 'RWP', 'WPB', 'PBG', 'BGW'...
# PGR         [[5, ['GRW', 'RWP', 'WPB', 'PBG', 'BGW']]]
# PGW                [[4, ['GWR', 'WRB', 'RBG', 'BGW']]]
# PRB                              [[2, ['RBG', 'BGW']]]
# PRG         [[5, ['RGW', 'GWP', 'WPB', 'PBG', 'BGW']]]
# PRW  [[6, ['RWG', 'WGP', 'GPR', 'PRB', 'RBG', 'BGW']]]
# PWB  [[6, ['WBG', 'BGP', 'GPR', 'PRB', 'RBG', 'BGW'...
# PWG         [[5, ['WGR', 'GRP', 'RPB', 'PBG', 'BGW']]]
# PWR                       [[3, ['WRB', 'RBG', 'BGW']]]
# RBG                                     [[1, ['BGW']]]
# RBP         [[5, ['BPW', 'PWR', 'WRB', 'RBG', 'BGW']]]
# RBW         [[5, ['BWP', 'WPR', 'PRB', 'RBG', 'BGW']]]
# RGB  [[6, ['GBP', 'BPW', 'PWR', 'WRB', 'RBG', 'BGW'...
# RGP         [[5, ['GPW', 'PWR', 'WRB', 'RBG', 'BGW']]]
# RGW                [[4, ['GWP', 'WPB', 'PBG', 'BGW']]]
# RPB                              [[2, ['PBG', 'BGW']]]
# RPG         [[5, ['PGW', 'GWR', 'WRB', 'RBG', 'BGW']]]
# RPW  [[6, ['PWG', 'WGR', 'GRP', 'RPB', 'PBG', 'BGW']]]
# RWB  [[6, ['WBG', 'BGP', 'GPR', 'PRB', 'RBG', 'BGW'...
# RWG         [[5, ['WGP', 'GPR', 'PRB', 'RBG', 'BGW']]]
# RWP                       [[3, ['WPB', 'PBG', 'BGW']]]
# WBG  [[5, ['BGP', 'GPR', 'PRB', 'RBG', 'BGW']], [5,...
# WBP  [[6, ['BPG', 'PGW', 'GWR', 'WRB', 'RBG', 'BGW']]]
# WBR  [[6, ['BRG', 'RGW', 'GWP', 'WPB', 'PBG', 'BGW']]]
# WGB  [[6, ['GBP', 'BPW', 'PWR', 'WRB', 'RBG', 'BGW'...
# WGP                [[4, ['GPR', 'PRB', 'RBG', 'BGW']]]
# WGR                [[4, ['GRP', 'RPB', 'PBG', 'BGW']]]
# WPB                              [[2, ['PBG', 'BGW']]]
# WPG  [[6, ['PGR', 'GRW', 'RWP', 'WPB', 'PBG', 'BGW']]]
# WPR                       [[3, ['PRB', 'RBG', 'BGW']]]
# WRB                              [[2, ['RBG', 'BGW']]]
# WRG  [[6, ['RGP', 'GPW', 'PWR', 'WRB', 'RBG', 'BGW']]]
# WRP                       [[3, ['RPB', 'PBG', 'BGW']]]
#
#                                                    BPG  \
# BGP  [[5, ['GPR', 'PRW', 'RWB', 'WBP', 'BPG']], [5,...
# BGR                [[4, ['GRW', 'RWB', 'WBP', 'BPG']]]
# BGW                [[4, ['GWR', 'WRB', 'RBP', 'BPG']]]
# BPG                                                NaN
# BPR                [[4, ['PRW', 'RWB', 'WBP', 'BPG']]]
# BPW                [[4, ['PWR', 'WRB', 'RBP', 'BPG']]]
# BRG                [[4, ['RGW', 'GWB', 'WBP', 'BPG']]]
# BRP         [[5, ['RPG', 'PGW', 'GWB', 'WBP', 'BPG']]]
# BRW  [[6, ['RWP', 'WPG', 'PGR', 'GRB', 'RBP', 'BPG']]]
# BWG                [[4, ['WGR', 'GRB', 'RBP', 'BPG']]]
# BWP         [[5, ['WPG', 'PGR', 'GRB', 'RBP', 'BPG']]]
# BWR  [[6, ['WRP', 'RPG', 'PGW', 'GWB', 'WBP', 'BPG']]]
# GBP  [[5, ['BPR', 'PRW', 'RWB', 'WBP', 'BPG']], [5,...
# GBR  [[6, ['BRP', 'RPG', 'PGW', 'GWB', 'WBP', 'BPG']]]
# GBW  [[6, ['BWP', 'WPG', 'PGR', 'GRB', 'RBP', 'BPG']]]
# GPB  [[6, ['PBR', 'BRG', 'RGW', 'GWB', 'WBP', 'BPG'...
# GPR                [[4, ['PRW', 'RWB', 'WBP', 'BPG']]]
# GPW                [[4, ['PWR', 'WRB', 'RBP', 'BPG']]]
# GRB                              [[2, ['RBP', 'BPG']]]
# GRP  [[6, ['RPW', 'PWG', 'WGR', 'GRB', 'RBP', 'BPG']]]
# GRW                       [[3, ['RWB', 'WBP', 'BPG']]]
# GWB                              [[2, ['WBP', 'BPG']]]
# GWP  [[6, ['WPR', 'PRG', 'RGW', 'GWB', 'WBP', 'BPG']]]
# GWR                       [[3, ['WRB', 'RBP', 'BPG']]]
# PBG  [[5, ['BGR', 'GRW', 'RWB', 'WBP', 'BPG']], [5,...
# PBR         [[5, ['BRG', 'RGW', 'GWB', 'WBP', 'BPG']]]
# PBW         [[5, ['BWG', 'WGR', 'GRB', 'RBP', 'BPG']]]
# PGB  [[7, ['GBR', 'BRP', 'RPG', 'PGW', 'GWB', 'WBP'...
# PGR                       [[3, ['GRB', 'RBP', 'BPG']]]
# PGW                       [[3, ['GWB', 'WBP', 'BPG']]]
# PRB  [[6, ['RBG', 'BGW', 'GWR', 'WRB', 'RBP', 'BPG'...
# PRG                [[4, ['RGW', 'GWB', 'WBP', 'BPG']]]
# PRW                       [[3, ['RWB', 'WBP', 'BPG']]]
# PWB  [[6, ['WBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPG'...
# PWG                [[4, ['WGR', 'GRB', 'RBP', 'BPG']]]
# PWR                       [[3, ['WRB', 'RBP', 'BPG']]]
# RBG         [[5, ['BGW', 'GWR', 'WRB', 'RBP', 'BPG']]]
# RBP                                     [[1, ['BPG']]]
# RBW         [[5, ['BWG', 'WGR', 'GRB', 'RBP', 'BPG']]]
# RGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBP', 'BPG'...
# RGP         [[5, ['GPW', 'PWR', 'WRB', 'RBP', 'BPG']]]
# RGW                       [[3, ['GWB', 'WBP', 'BPG']]]
# RPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPG'...
# RPG                [[4, ['PGW', 'GWB', 'WBP', 'BPG']]]
# RPW         [[5, ['PWG', 'WGR', 'GRB', 'RBP', 'BPG']]]
# RWB                              [[2, ['WBP', 'BPG']]]
# RWG  [[6, ['WGP', 'GPR', 'PRW', 'RWB', 'WBP', 'BPG']]]
# RWP         [[5, ['WPG', 'PGR', 'GRB', 'RBP', 'BPG']]]
# WBG         [[5, ['BGR', 'GRW', 'RWB', 'WBP', 'BPG']]]
# WBP                                     [[1, ['BPG']]]
# WBR         [[5, ['BRG', 'RGW', 'GWB', 'WBP', 'BPG']]]
# WGB  [[6, ['GBP', 'BPR', 'PRW', 'RWB', 'WBP', 'BPG'...
# WGP         [[5, ['GPR', 'PRW', 'RWB', 'WBP', 'BPG']]]
# WGR                       [[3, ['GRB', 'RBP', 'BPG']]]
# WPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPG'...
# WPG                [[4, ['PGR', 'GRB', 'RBP', 'BPG']]]
# WPR         [[5, ['PRG', 'RGW', 'GWB', 'WBP', 'BPG']]]
# WRB                              [[2, ['RBP', 'BPG']]]
# WRG  [[6, ['RGP', 'GPW', 'PWR', 'WRB', 'RBP', 'BPG']]]
# WRP         [[5, ['RPG', 'PGW', 'GWB', 'WBP', 'BPG']]]
#
#                                                    BPR  \
# BGP         [[5, ['GPR', 'PRW', 'RWB', 'WBP', 'BPR']]]
# BGR                [[4, ['GRW', 'RWB', 'WBP', 'BPR']]]
# BGW  [[6, ['GWP', 'WPR', 'PRG', 'RGB', 'GBP', 'BPR']]]
# BPG                [[4, ['PGW', 'GWB', 'WBP', 'BPR']]]
# BPR                                                NaN
# BPW                [[4, ['PWG', 'WGB', 'GBP', 'BPR']]]
# BRG                [[4, ['RGW', 'GWB', 'WBP', 'BPR']]]
# BRP  [[5, ['RPG', 'PGW', 'GWB', 'WBP', 'BPR']], [5,...
# BRW                [[4, ['RWG', 'WGB', 'GBP', 'BPR']]]
# BWG  [[6, ['WGP', 'GPR', 'PRW', 'RWB', 'WBP', 'BPR']]]
# BWP         [[5, ['WPR', 'PRG', 'RGB', 'GBP', 'BPR']]]
# BWR                [[4, ['WRG', 'RGB', 'GBP', 'BPR']]]
# GBP                                     [[1, ['BPR']]]
# GBR         [[5, ['BRW', 'RWG', 'WGB', 'GBP', 'BPR']]]
# GBW         [[5, ['BWR', 'WRG', 'RGB', 'GBP', 'BPR']]]
# GPB  [[6, ['PBR', 'BRG', 'RGW', 'GWB', 'WBP', 'BPR'...
# GPR                [[4, ['PRW', 'RWB', 'WBP', 'BPR']]]
# GPW         [[5, ['PWR', 'WRG', 'RGB', 'GBP', 'BPR']]]
# GRB  [[6, ['RBP', 'BPG', 'PGW', 'GWB', 'WBP', 'BPR'...
# GRP         [[5, ['RPW', 'PWG', 'WGB', 'GBP', 'BPR']]]
# GRW                       [[3, ['RWB', 'WBP', 'BPR']]]
# GWB                              [[2, ['WBP', 'BPR']]]
# GWP         [[5, ['WPR', 'PRG', 'RGB', 'GBP', 'BPR']]]
# GWR  [[6, ['WRP', 'RPG', 'PGW', 'GWB', 'WBP', 'BPR']]]
# PBG         [[5, ['BGR', 'GRW', 'RWB', 'WBP', 'BPR']]]
# PBR  [[5, ['BRG', 'RGW', 'GWB', 'WBP', 'BPR']], [5,...
# PBW         [[5, ['BWR', 'WRG', 'RGB', 'GBP', 'BPR']]]
# PGB  [[6, ['GBR', 'BRW', 'RWG', 'WGB', 'GBP', 'BPR'...
# PGR                [[4, ['GRW', 'RWB', 'WBP', 'BPR']]]
# PGW                       [[3, ['GWB', 'WBP', 'BPR']]]
# PRB  [[7, ['RBG', 'BGP', 'GPR', 'PRW', 'RWB', 'WBP'...
# PRG                       [[3, ['RGB', 'GBP', 'BPR']]]
# PRW                       [[3, ['RWB', 'WBP', 'BPR']]]
# PWB  [[6, ['WBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPR'...
# PWG                       [[3, ['WGB', 'GBP', 'BPR']]]
# PWR                [[4, ['WRG', 'RGB', 'GBP', 'BPR']]]
# RBG  [[6, ['BGP', 'GPR', 'PRW', 'RWB', 'WBP', 'BPR']]]
# RBP  [[5, ['BPG', 'PGW', 'GWB', 'WBP', 'BPR']], [5,...
# RBW  [[6, ['BWP', 'WPR', 'PRG', 'RGB', 'GBP', 'BPR']]]
# RGB                              [[2, ['GBP', 'BPR']]]
# RGP  [[6, ['GPW', 'PWR', 'WRG', 'RGB', 'GBP', 'BPR']]]
# RGW                       [[3, ['GWB', 'WBP', 'BPR']]]
# RPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPR'...
# RPG                [[4, ['PGW', 'GWB', 'WBP', 'BPR']]]
# RPW                [[4, ['PWG', 'WGB', 'GBP', 'BPR']]]
# RWB                              [[2, ['WBP', 'BPR']]]
# RWG                       [[3, ['WGB', 'GBP', 'BPR']]]
# RWP  [[6, ['WPG', 'PGR', 'GRW', 'RWB', 'WBP', 'BPR']]]
# WBG         [[5, ['BGR', 'GRW', 'RWB', 'WBP', 'BPR']]]
# WBP                                     [[1, ['BPR']]]
# WBR         [[5, ['BRG', 'RGW', 'GWB', 'WBP', 'BPR']]]
# WGB                              [[2, ['GBP', 'BPR']]]
# WGP         [[5, ['GPR', 'PRW', 'RWB', 'WBP', 'BPR']]]
# WGR  [[6, ['GRP', 'RPW', 'PWG', 'WGB', 'GBP', 'BPR']]]
# WPB  [[6, ['PBG', 'BGR', 'GRW', 'RWB', 'WBP', 'BPR'...
# WPG         [[5, ['PGR', 'GRW', 'RWB', 'WBP', 'BPR']]]
# WPR                [[4, ['PRG', 'RGB', 'GBP', 'BPR']]]
# WRB  [[6, ['RBP', 'BPG', 'PGW', 'GWB', 'WBP', 'BPR'...
# WRG                       [[3, ['RGB', 'GBP', 'BPR']]]
# WRP         [[5, ['RPG', 'PGW', 'GWB', 'WBP', 'BPR']]]
#
#                                                    BPW  \
# BGP         [[5, ['GPW', 'PWR', 'WRB', 'RBP', 'BPW']]]
# BGR  [[6, ['GRP', 'RPW', 'PWG', 'WGB', 'GBP', 'BPW']]]
# BGW                [[4, ['GWR', 'WRB', 'RBP', 'BPW']]]
# BPG                [[4, ['PGR', 'GRB', 'RBP', 'BPW']]]
# BPR                [[4, ['PRG', 'RGB', 'GBP', 'BPW']]]
# BPW                                                NaN
# BRG  [[6, ['RGP', 'GPW', 'PWR', 'WRB', 'RBP', 'BPW']]]
# BRP         [[5, ['RPW', 'PWG', 'WGB', 'GBP', 'BPW']]]
# BRW                [[4, ['RWG', 'WGB', 'GBP', 'BPW']]]
# BWG                [[4, ['WGR', 'GRB', 'RBP', 'BPW']]]
# BWP  [[5, ['WPG', 'PGR', 'GRB', 'RBP', 'BPW']], [5,...
# BWR                [[4, ['WRG', 'RGB', 'GBP', 'BPW']]]
# GBP                                     [[1, ['BPW']]]
# GBR         [[5, ['BRW', 'RWG', 'WGB', 'GBP', 'BPW']]]
# GBW         [[5, ['BWR', 'WRG', 'RGB', 'GBP', 'BPW']]]
# GPB  [[6, ['PBR', 'BRW', 'RWG', 'WGB', 'GBP', 'BPW'...
# GPR         [[5, ['PRW', 'RWG', 'WGB', 'GBP', 'BPW']]]
# GPW                [[4, ['PWR', 'WRB', 'RBP', 'BPW']]]
# GRB                              [[2, ['RBP', 'BPW']]]
# GRP         [[5, ['RPW', 'PWG', 'WGB', 'GBP', 'BPW']]]
# GRW  [[6, ['RWP', 'WPG', 'PGR', 'GRB', 'RBP', 'BPW']]]
# GWB  [[6, ['WBP', 'BPG', 'PGR', 'GRB', 'RBP', 'BPW'...
# GWP         [[5, ['WPR', 'PRG', 'RGB', 'GBP', 'BPW']]]
# GWR                       [[3, ['WRB', 'RBP', 'BPW']]]
# PBG         [[5, ['BGW', 'GWR', 'WRB', 'RBP', 'BPW']]]
# PBR         [[5, ['BRW', 'RWG', 'WGB', 'GBP', 'BPW']]]
# PBW  [[5, ['BWG', 'WGR', 'GRB', 'RBP', 'BPW']], [5,...
# PGB  [[6, ['GBR', 'BRW', 'RWG', 'WGB', 'GBP', 'BPW'...
# PGR                       [[3, ['GRB', 'RBP', 'BPW']]]
# PGW                [[4, ['GWR', 'WRB', 'RBP', 'BPW']]]
# PRB  [[6, ['RBG', 'BGW', 'GWR', 'WRB', 'RBP', 'BPW'...
# PRG                       [[3, ['RGB', 'GBP', 'BPW']]]
# PRW                [[4, ['RWG', 'WGB', 'GBP', 'BPW']]]
# PWB  [[7, ['WBG', 'BGP', 'GPW', 'PWR', 'WRB', 'RBP'...
# PWG                       [[3, ['WGB', 'GBP', 'BPW']]]
# PWR                       [[3, ['WRB', 'RBP', 'BPW']]]
# RBG         [[5, ['BGW', 'GWR', 'WRB', 'RBP', 'BPW']]]
# RBP                                     [[1, ['BPW']]]
# RBW         [[5, ['BWG', 'WGR', 'GRB', 'RBP', 'BPW']]]
# RGB                              [[2, ['GBP', 'BPW']]]
# RGP         [[5, ['GPW', 'PWR', 'WRB', 'RBP', 'BPW']]]
# RGW  [[6, ['GWP', 'WPR', 'PRG', 'RGB', 'GBP', 'BPW']]]
# RPB  [[6, ['PBG', 'BGW', 'GWR', 'WRB', 'RBP', 'BPW'...
# RPG         [[5, ['PGW', 'GWR', 'WRB', 'RBP', 'BPW']]]
# RPW                [[4, ['PWG', 'WGB', 'GBP', 'BPW']]]
# RWB  [[6, ['WBP', 'BPG', 'PGR', 'GRB', 'RBP', 'BPW'...
# RWG                       [[3, ['WGB', 'GBP', 'BPW']]]
# RWP         [[5, ['WPG', 'PGR', 'GRB', 'RBP', 'BPW']]]
# WBG  [[6, ['BGP', 'GPW', 'PWR', 'WRB', 'RBP', 'BPW']]]
# WBP  [[5, ['BPG', 'PGR', 'GRB', 'RBP', 'BPW']], [5,...
# WBR  [[6, ['BRP', 'RPW', 'PWG', 'WGB', 'GBP', 'BPW']]]
# WGB                              [[2, ['GBP', 'BPW']]]
# WGP  [[6, ['GPR', 'PRW', 'RWG', 'WGB', 'GBP', 'BPW']]]
# WGR                       [[3, ['GRB', 'RBP', 'BPW']]]
# WPB  [[6, ['PBG', 'BGW', 'GWR', 'WRB', 'RBP', 'BPW'...
# WPG                [[4, ['PGR', 'GRB', 'RBP', 'BPW']]]
# WPR                [[4, ['PRG', 'RGB', 'GBP', 'BPW']]]
# WRB                              [[2, ['RBP', 'BPW']]]
# WRG                       [[3, ['RGB', 'GBP', 'BPW']]]
# WRP  [[6, ['RPG', 'PGW', 'GWR', 'WRB', 'RBP', 'BPW']]]
#
#                                                    BRG  \
# BGP                [[4, ['GPW', 'PWB', 'WBR', 'BRG']]]
# BGR  [[5, ['GRP', 'RPW', 'PWB', 'WBR', 'BRG']], [5,...
# BGW                [[4, ['GWP', 'WPB', 'PBR', 'BRG']]]
# BPG                [[4, ['PGW', 'GWB', 'WBR', 'BRG']]]
# BPR         [[5, ['PRG', 'RGW', 'GWB', 'WBR', 'BRG']]]
# BPW  [[6, ['PWR', 'WRG', 'RGP', 'GPB', 'PBR', 'BRG']]]
# BRG                                                NaN
# BRP                [[4, ['RPW', 'PWB', 'WBR', 'BRG']]]
# BRW                [[4, ['RWP', 'WPB', 'PBR', 'BRG']]]
# BWG                [[4, ['WGP', 'GPB', 'PBR', 'BRG']]]
# BWP  [[6, ['WPR', 'PRG', 'RGW', 'GWB', 'WBR', 'BRG']]]
# BWR         [[5, ['WRG', 'RGP', 'GPB', 'PBR', 'BRG']]]
# GBP  [[6, ['BPR', 'PRG', 'RGW', 'GWB', 'WBR', 'BRG']]]
# GBR  [[5, ['BRP', 'RPW', 'PWB', 'WBR', 'BRG']], [5,...
# GBW  [[6, ['BWR', 'WRG', 'RGP', 'GPB', 'PBR', 'BRG']]]
# GPB                              [[2, ['PBR', 'BRG']]]
# GPR  [[6, ['PRW', 'RWG', 'WGP', 'GPB', 'PBR', 'BRG']]]
# GPW                       [[3, ['PWB', 'WBR', 'BRG']]]
# GRB  [[6, ['RBP', 'BPG', 'PGW', 'GWB', 'WBR', 'BRG'...
# GRP                [[4, ['RPW', 'PWB', 'WBR', 'BRG']]]
# GRW                [[4, ['RWP', 'WPB', 'PBR', 'BRG']]]
# GWB                              [[2, ['WBR', 'BRG']]]
# GWP                       [[3, ['WPB', 'PBR', 'BRG']]]
# GWR  [[6, ['WRP', 'RPG', 'PGW', 'GWB', 'WBR', 'BRG']]]
# PBG         [[5, ['BGW', 'GWP', 'WPB', 'PBR', 'BRG']]]
# PBR                                     [[1, ['BRG']]]
# PBW         [[5, ['BWG', 'WGP', 'GPB', 'PBR', 'BRG']]]
# PGB  [[6, ['GBR', 'BRP', 'RPW', 'PWB', 'WBR', 'BRG'...
# PGR         [[5, ['GRW', 'RWP', 'WPB', 'PBR', 'BRG']]]
# PGW                       [[3, ['GWB', 'WBR', 'BRG']]]
# PRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRG'...
# PRG                [[4, ['RGW', 'GWB', 'WBR', 'BRG']]]
# PRW         [[5, ['RWG', 'WGP', 'GPB', 'PBR', 'BRG']]]
# PWB                              [[2, ['WBR', 'BRG']]]
# PWG  [[6, ['WGR', 'GRP', 'RPW', 'PWB', 'WBR', 'BRG']]]
# PWR         [[5, ['WRG', 'RGP', 'GPB', 'PBR', 'BRG']]]
# RBG  [[5, ['BGP', 'GPW', 'PWB', 'WBR', 'BRG']], [5,...
# RBP         [[5, ['BPG', 'PGW', 'GWB', 'WBR', 'BRG']]]
# RBW         [[5, ['BWG', 'WGP', 'GPB', 'PBR', 'BRG']]]
# RGB  [[7, ['GBP', 'BPR', 'PRG', 'RGW', 'GWB', 'WBR'...
# RGP                       [[3, ['GPB', 'PBR', 'BRG']]]
# RGW                       [[3, ['GWB', 'WBR', 'BRG']]]
# RPB  [[6, ['PBG', 'BGW', 'GWP', 'WPB', 'PBR', 'BRG'...
# RPG                [[4, ['PGW', 'GWB', 'WBR', 'BRG']]]
# RPW                       [[3, ['PWB', 'WBR', 'BRG']]]
# RWB  [[6, ['WBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRG'...
# RWG                [[4, ['WGP', 'GPB', 'PBR', 'BRG']]]
# RWP                       [[3, ['WPB', 'PBR', 'BRG']]]
# WBG         [[5, ['BGP', 'GPW', 'PWB', 'WBR', 'BRG']]]
# WBP         [[5, ['BPG', 'PGW', 'GWB', 'WBR', 'BRG']]]
# WBR                                     [[1, ['BRG']]]
# WGB  [[6, ['GBR', 'BRP', 'RPW', 'PWB', 'WBR', 'BRG'...
# WGP                       [[3, ['GPB', 'PBR', 'BRG']]]
# WGR         [[5, ['GRP', 'RPW', 'PWB', 'WBR', 'BRG']]]
# WPB                              [[2, ['PBR', 'BRG']]]
# WPG  [[6, ['PGR', 'GRW', 'RWP', 'WPB', 'PBR', 'BRG']]]
# WPR         [[5, ['PRG', 'RGW', 'GWB', 'WBR', 'BRG']]]
# WRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRG'...
# WRG                [[4, ['RGP', 'GPB', 'PBR', 'BRG']]]
# WRP         [[5, ['RPG', 'PGW', 'GWB', 'WBR', 'BRG']]]
#
#                                                    BRP  \
# BGP                [[4, ['GPW', 'PWB', 'WBR', 'BRP']]]
# BGR         [[5, ['GRP', 'RPW', 'PWB', 'WBR', 'BRP']]]
# BGW  [[6, ['GWR', 'WRP', 'RPG', 'PGB', 'GBR', 'BRP']]]
# BPG                [[4, ['PGW', 'GWB', 'WBR', 'BRP']]]
# BPR  [[5, ['PRG', 'RGW', 'GWB', 'WBR', 'BRP']], [5,...
# BPW                [[4, ['PWG', 'WGB', 'GBR', 'BRP']]]
# BRG                [[4, ['RGW', 'GWB', 'WBR', 'BRP']]]
# BRP                                                NaN
# BRW                [[4, ['RWG', 'WGB', 'GBR', 'BRP']]]
# BWG  [[6, ['WGR', 'GRP', 'RPW', 'PWB', 'WBR', 'BRP']]]
# BWP                [[4, ['WPG', 'PGB', 'GBR', 'BRP']]]
# BWR         [[5, ['WRP', 'RPG', 'PGB', 'GBR', 'BRP']]]
# GBP         [[5, ['BPW', 'PWG', 'WGB', 'GBR', 'BRP']]]
# GBR                                     [[1, ['BRP']]]
# GBW         [[5, ['BWP', 'WPG', 'PGB', 'GBR', 'BRP']]]
# GPB  [[6, ['PBR', 'BRG', 'RGW', 'GWB', 'WBR', 'BRP'...
# GPR         [[5, ['PRW', 'RWG', 'WGB', 'GBR', 'BRP']]]
# GPW                       [[3, ['PWB', 'WBR', 'BRP']]]
# GRB  [[6, ['RBP', 'BPG', 'PGW', 'GWB', 'WBR', 'BRP'...
# GRP                [[4, ['RPW', 'PWB', 'WBR', 'BRP']]]
# GRW         [[5, ['RWP', 'WPG', 'PGB', 'GBR', 'BRP']]]
# GWB                              [[2, ['WBR', 'BRP']]]
# GWP  [[6, ['WPR', 'PRG', 'RGW', 'GWB', 'WBR', 'BRP']]]
# GWR         [[5, ['WRP', 'RPG', 'PGB', 'GBR', 'BRP']]]
# PBG  [[6, ['BGR', 'GRP', 'RPW', 'PWB', 'WBR', 'BRP']]]
# PBR  [[5, ['BRG', 'RGW', 'GWB', 'WBR', 'BRP']], [5,...
# PBW  [[6, ['BWR', 'WRP', 'RPG', 'PGB', 'GBR', 'BRP']]]
# PGB                              [[2, ['GBR', 'BRP']]]
# PGR  [[6, ['GRW', 'RWP', 'WPG', 'PGB', 'GBR', 'BRP']]]
# PGW                       [[3, ['GWB', 'WBR', 'BRP']]]
# PRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRP'...
# PRG                [[4, ['RGW', 'GWB', 'WBR', 'BRP']]]
# PRW                [[4, ['RWG', 'WGB', 'GBR', 'BRP']]]
# PWB                              [[2, ['WBR', 'BRP']]]
# PWG                       [[3, ['WGB', 'GBR', 'BRP']]]
# PWR  [[6, ['WRG', 'RGP', 'GPW', 'PWB', 'WBR', 'BRP']]]
# RBG         [[5, ['BGP', 'GPW', 'PWB', 'WBR', 'BRP']]]
# RBP  [[5, ['BPG', 'PGW', 'GWB', 'WBR', 'BRP']], [5,...
# RBW         [[5, ['BWP', 'WPG', 'PGB', 'GBR', 'BRP']]]
# RGB  [[6, ['GBP', 'BPW', 'PWG', 'WGB', 'GBR', 'BRP'...
# RGP                [[4, ['GPW', 'PWB', 'WBR', 'BRP']]]
# RGW                       [[3, ['GWB', 'WBR', 'BRP']]]
# RPB  [[7, ['PBG', 'BGR', 'GRP', 'RPW', 'PWB', 'WBR'...
# RPG                       [[3, ['PGB', 'GBR', 'BRP']]]
# RPW                       [[3, ['PWB', 'WBR', 'BRP']]]
# RWB  [[6, ['WBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRP'...
# RWG                       [[3, ['WGB', 'GBR', 'BRP']]]
# RWP                [[4, ['WPG', 'PGB', 'GBR', 'BRP']]]
# WBG         [[5, ['BGP', 'GPW', 'PWB', 'WBR', 'BRP']]]
# WBP         [[5, ['BPG', 'PGW', 'GWB', 'WBR', 'BRP']]]
# WBR                                     [[1, ['BRP']]]
# WGB                              [[2, ['GBR', 'BRP']]]
# WGP  [[6, ['GPR', 'PRW', 'RWG', 'WGB', 'GBR', 'BRP']]]
# WGR         [[5, ['GRP', 'RPW', 'PWB', 'WBR', 'BRP']]]
# WPB  [[6, ['PBR', 'BRG', 'RGW', 'GWB', 'WBR', 'BRP'...
# WPG                       [[3, ['PGB', 'GBR', 'BRP']]]
# WPR         [[5, ['PRG', 'RGW', 'GWB', 'WBR', 'BRP']]]
# WRB  [[6, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR', 'BRP'...
# WRG         [[5, ['RGP', 'GPW', 'PWB', 'WBR', 'BRP']]]
# WRP                [[4, ['RPG', 'PGB', 'GBR', 'BRP']]]
#
#                                                    BRW  \
# BGP  [[6, ['GPR', 'PRW', 'RWG', 'WGB', 'GBR', 'BRW']]]
# BGR         [[5, ['GRW', 'RWP', 'WPB', 'PBR', 'BRW']]]
# BGW                [[4, ['GWP', 'WPB', 'PBR', 'BRW']]]
# BPG  [[6, ['PGR', 'GRW', 'RWP', 'WPB', 'PBR', 'BRW']]]
# BPR         [[5, ['PRW', 'RWG', 'WGB', 'GBR', 'BRW']]]
# BPW                [[4, ['PWG', 'WGB', 'GBR', 'BRW']]]
# BRG                [[4, ['RGP', 'GPB', 'PBR', 'BRW']]]
# BRP                [[4, ['RPG', 'PGB', 'GBR', 'BRW']]]
# BRW                                                NaN
# BWG                [[4, ['WGP', 'GPB', 'PBR', 'BRW']]]
# BWP                [[4, ['WPG', 'PGB', 'GBR', 'BRW']]]
# BWR  [[5, ['WRG', 'RGP', 'GPB', 'PBR', 'BRW']], [5,...
# GBP         [[5, ['BPW', 'PWG', 'WGB', 'GBR', 'BRW']]]
# GBR                                     [[1, ['BRW']]]
# GBW         [[5, ['BWP', 'WPG', 'PGB', 'GBR', 'BRW']]]
# GPB                              [[2, ['PBR', 'BRW']]]
# GPR         [[5, ['PRW', 'RWG', 'WGB', 'GBR', 'BRW']]]
# GPW  [[6, ['PWR', 'WRG', 'RGP', 'GPB', 'PBR', 'BRW']]]
# GRB  [[6, ['RBP', 'BPW', 'PWG', 'WGB', 'GBR', 'BRW'...
# GRP         [[5, ['RPW', 'PWG', 'WGB', 'GBR', 'BRW']]]
# GRW                [[4, ['RWP', 'WPB', 'PBR', 'BRW']]]
# GWB  [[6, ['WBR', 'BRG', 'RGP', 'GPB', 'PBR', 'BRW'...
# GWP                       [[3, ['WPB', 'PBR', 'BRW']]]
# GWR         [[5, ['WRP', 'RPG', 'PGB', 'GBR', 'BRW']]]
# PBG         [[5, ['BGW', 'GWP', 'WPB', 'PBR', 'BRW']]]
# PBR                                     [[1, ['BRW']]]
# PBW         [[5, ['BWG', 'WGP', 'GPB', 'PBR', 'BRW']]]
# PGB                              [[2, ['GBR', 'BRW']]]
# PGR         [[5, ['GRW', 'RWP', 'WPB', 'PBR', 'BRW']]]
# PGW  [[6, ['GWR', 'WRP', 'RPG', 'PGB', 'GBR', 'BRW']]]
# PRB  [[6, ['RBG', 'BGW', 'GWP', 'WPB', 'PBR', 'BRW'...
# PRG         [[5, ['RGW', 'GWP', 'WPB', 'PBR', 'BRW']]]
# PRW                [[4, ['RWG', 'WGB', 'GBR', 'BRW']]]
# PWB  [[6, ['WBR', 'BRG', 'RGP', 'GPB', 'PBR', 'BRW'...
# PWG                       [[3, ['WGB', 'GBR', 'BRW']]]
# PWR         [[5, ['WRG', 'RGP', 'GPB', 'PBR', 'BRW']]]
# RBG         [[5, ['BGW', 'GWP', 'WPB', 'PBR', 'BRW']]]
# RBP         [[5, ['BPW', 'PWG', 'WGB', 'GBR', 'BRW']]]
# RBW  [[5, ['BWG', 'WGP', 'GPB', 'PBR', 'BRW']], [5,...
# RGB  [[6, ['GBP', 'BPW', 'PWG', 'WGB', 'GBR', 'BRW'...
# RGP                       [[3, ['GPB', 'PBR', 'BRW']]]
# RGW                [[4, ['GWP', 'WPB', 'PBR', 'BRW']]]
# RPB  [[6, ['PBG', 'BGW', 'GWP', 'WPB', 'PBR', 'BRW'...
# RPG                       [[3, ['PGB', 'GBR', 'BRW']]]
# RPW                [[4, ['PWG', 'WGB', 'GBR', 'BRW']]]
# RWB  [[7, ['WBG', 'BGR', 'GRW', 'RWP', 'WPB', 'PBR'...
# RWG                       [[3, ['WGB', 'GBR', 'BRW']]]
# RWP                       [[3, ['WPB', 'PBR', 'BRW']]]
# WBG  [[6, ['BGR', 'GRW', 'RWP', 'WPB', 'PBR', 'BRW']]]
# WBP  [[6, ['BPR', 'PRW', 'RWG', 'WGB', 'GBR', 'BRW']]]
# WBR  [[5, ['BRG', 'RGP', 'GPB', 'PBR', 'BRW']], [5,...
# WGB                              [[2, ['GBR', 'BRW']]]
# WGP                       [[3, ['GPB', 'PBR', 'BRW']]]
# WGR  [[6, ['GRP', 'RPW', 'PWG', 'WGB', 'GBR', 'BRW']]]
# WPB                              [[2, ['PBR', 'BRW']]]
# WPG                       [[3, ['PGB', 'GBR', 'BRW']]]
# WPR  [[6, ['PRG', 'RGW', 'GWP', 'WPB', 'PBR', 'BRW']]]
# WRB  [[6, ['RBG', 'BGW', 'GWP', 'WPB', 'PBR', 'BRW'...
# WRG                [[4, ['RGP', 'GPB', 'PBR', 'BRW']]]
# WRP                [[4, ['RPG', 'PGB', 'GBR', 'BRW']]]
#
#                                                    BWG  ...  \
# BGP                [[4, ['GPR', 'PRB', 'RBW', 'BWG']]]  ...
# BGR                [[4, ['GRP', 'RPB', 'PBW', 'BWG']]]  ...
# BGW  [[5, ['GWP', 'WPR', 'PRB', 'RBW', 'BWG']], [5,...  ...
# BPG                [[4, ['PGR', 'GRB', 'RBW', 'BWG']]]  ...
# BPR  [[6, ['PRW', 'RWG', 'WGP', 'GPB', 'PBW', 'BWG']]]  ...
# BPW         [[5, ['PWG', 'WGR', 'GRB', 'RBW', 'BWG']]]  ...
# BRG                [[4, ['RGP', 'GPB', 'PBW', 'BWG']]]  ...
# BRP  [[6, ['RPW', 'PWG', 'WGR', 'GRB', 'RBW', 'BWG']]]  ...
# BRW         [[5, ['RWG', 'WGP', 'GPB', 'PBW', 'BWG']]]  ...
# BWG                                                NaN  ...
# BWP                [[4, ['WPR', 'PRB', 'RBW', 'BWG']]]  ...
# BWR                [[4, ['WRP', 'RPB', 'PBW', 'BWG']]]  ...
# GBP  [[6, ['BPW', 'PWG', 'WGR', 'GRB', 'RBW', 'BWG']]]  ...
# GBR  [[6, ['BRW', 'RWG', 'WGP', 'GPB', 'PBW', 'BWG']]]  ...
# GBW  [[5, ['BWP', 'WPR', 'PRB', 'RBW', 'BWG']], [5,...  ...
# GPB                              [[2, ['PBW', 'BWG']]]  ...
# GPR                       [[3, ['PRB', 'RBW', 'BWG']]]  ...
# GPW  [[6, ['PWR', 'WRG', 'RGP', 'GPB', 'PBW', 'BWG']]]  ...
# GRB                              [[2, ['RBW', 'BWG']]]  ...
# GRP                       [[3, ['RPB', 'PBW', 'BWG']]]  ...
# GRW  [[6, ['RWP', 'WPG', 'PGR', 'GRB', 'RBW', 'BWG']]]  ...
# GWB  [[6, ['WBP', 'BPG', 'PGR', 'GRB', 'RBW', 'BWG'...  ...
# GWP                [[4, ['WPR', 'PRB', 'RBW', 'BWG']]]  ...
# GWR                [[4, ['WRP', 'RPB', 'PBW', 'BWG']]]  ...
# PBG         [[5, ['BGR', 'GRP', 'RPB', 'PBW', 'BWG']]]  ...
# PBR         [[5, ['BRG', 'RGP', 'GPB', 'PBW', 'BWG']]]  ...
# PBW                                     [[1, ['BWG']]]  ...
# PGB  [[6, ['GBW', 'BWP', 'WPR', 'PRB', 'RBW', 'BWG'...  ...
# PGR                       [[3, ['GRB', 'RBW', 'BWG']]]  ...
# PGW         [[5, ['GWR', 'WRP', 'RPB', 'PBW', 'BWG']]]  ...
# PRB                              [[2, ['RBW', 'BWG']]]  ...
# PRG  [[6, ['RGW', 'GWP', 'WPR', 'PRB', 'RBW', 'BWG']]]  ...
# PRW         [[5, ['RWG', 'WGP', 'GPB', 'PBW', 'BWG']]]  ...
# PWB  [[6, ['WBG', 'BGP', 'GPR', 'PRB', 'RBW', 'BWG'...  ...
# PWG                [[4, ['WGR', 'GRB', 'RBW', 'BWG']]]  ...
# PWR         [[5, ['WRG', 'RGP', 'GPB', 'PBW', 'BWG']]]  ...
# RBG         [[5, ['BGP', 'GPR', 'PRB', 'RBW', 'BWG']]]  ...
# RBP         [[5, ['BPG', 'PGR', 'GRB', 'RBW', 'BWG']]]  ...
# RBW                                     [[1, ['BWG']]]  ...
# RGB  [[6, ['GBW', 'BWP', 'WPR', 'PRB', 'RBW', 'BWG'...  ...
# RGP                       [[3, ['GPB', 'PBW', 'BWG']]]  ...
# RGW         [[5, ['GWP', 'WPR', 'PRB', 'RBW', 'BWG']]]  ...
# RPB                              [[2, ['PBW', 'BWG']]]  ...
# RPG  [[6, ['PGW', 'GWR', 'WRP', 'RPB', 'PBW', 'BWG']]]  ...
# RPW         [[5, ['PWG', 'WGR', 'GRB', 'RBW', 'BWG']]]  ...
# RWB  [[6, ['WBG', 'BGP', 'GPR', 'PRB', 'RBW', 'BWG'...  ...
# RWG                [[4, ['WGP', 'GPB', 'PBW', 'BWG']]]  ...
# RWP         [[5, ['WPG', 'PGR', 'GRB', 'RBW', 'BWG']]]  ...
# WBG  [[5, ['BGP', 'GPR', 'PRB', 'RBW', 'BWG']], [5,...  ...
# WBP         [[5, ['BPG', 'PGR', 'GRB', 'RBW', 'BWG']]]  ...
# WBR         [[5, ['BRG', 'RGP', 'GPB', 'PBW', 'BWG']]]  ...
# WGB  [[7, ['GBP', 'BPW', 'PWG', 'WGR', 'GRB', 'RBW'...  ...
# WGP                       [[3, ['GPB', 'PBW', 'BWG']]]  ...
# WGR                       [[3, ['GRB', 'RBW', 'BWG']]]  ...
# WPB  [[6, ['PBG', 'BGR', 'GRP', 'RPB', 'PBW', 'BWG'...  ...
# WPG                [[4, ['PGR', 'GRB', 'RBW', 'BWG']]]  ...
# WPR                       [[3, ['PRB', 'RBW', 'BWG']]]  ...
# WRB  [[6, ['RBG', 'BGP', 'GPR', 'PRB', 'RBW', 'BWG'...  ...
# WRG                [[4, ['RGP', 'GPB', 'PBW', 'BWG']]]  ...
# WRP                       [[3, ['RPB', 'PBW', 'BWG']]]  ...
#
#                                                    WBR  \
# BGP                       [[3, ['GPW', 'PWB', 'WBR']]]
# BGR                [[4, ['GRP', 'RPW', 'PWB', 'WBR']]]
# BGW  [[6, ['GWP', 'WPR', 'PRG', 'RGW', 'GWB', 'WBR'...
# BPG                       [[3, ['PGW', 'GWB', 'WBR']]]
# BPR                [[4, ['PRG', 'RGW', 'GWB', 'WBR']]]
# BPW  [[6, ['PWG', 'WGR', 'GRP', 'RPW', 'PWB', 'WBR'...
# BRG                       [[3, ['RGW', 'GWB', 'WBR']]]
# BRP                       [[3, ['RPW', 'PWB', 'WBR']]]
# BRW  [[7, ['RWG', 'WGB', 'GBR', 'BRP', 'RPW', 'PWB'...
# BWG         [[5, ['WGR', 'GRP', 'RPW', 'PWB', 'WBR']]]
# BWP         [[5, ['WPR', 'PRG', 'RGW', 'GWB', 'WBR']]]
# BWR  [[5, ['WRG', 'RGP', 'GPW', 'PWB', 'WBR']], [5,...
# GBP         [[5, ['BPR', 'PRG', 'RGW', 'GWB', 'WBR']]]
# GBR                [[4, ['BRP', 'RPW', 'PWB', 'WBR']]]
# GBW  [[6, ['BWP', 'WPR', 'PRG', 'RGW', 'GWB', 'WBR'...
# GPB         [[5, ['PBR', 'BRG', 'RGW', 'GWB', 'WBR']]]
# GPR  [[6, ['PRB', 'RBG', 'BGP', 'GPW', 'PWB', 'WBR']]]
# GPW                              [[2, ['PWB', 'WBR']]]
# GRB         [[5, ['RBP', 'BPG', 'PGW', 'GWB', 'WBR']]]
# GRP                       [[3, ['RPW', 'PWB', 'WBR']]]
# GRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWB', 'WBR'...
# GWB                                     [[1, ['WBR']]]
# GWP         [[5, ['WPR', 'PRG', 'RGW', 'GWB', 'WBR']]]
# GWR         [[5, ['WRP', 'RPG', 'PGW', 'GWB', 'WBR']]]
# PBG         [[5, ['BGR', 'GRP', 'RPW', 'PWB', 'WBR']]]
# PBR                [[4, ['BRG', 'RGW', 'GWB', 'WBR']]]
# PBW  [[6, ['BWG', 'WGR', 'GRP', 'RPW', 'PWB', 'WBR'...
# PGB         [[5, ['GBR', 'BRP', 'RPW', 'PWB', 'WBR']]]
# PGR  [[6, ['GRB', 'RBP', 'BPG', 'PGW', 'GWB', 'WBR']]]
# PGW                              [[2, ['GWB', 'WBR']]]
# PRB         [[5, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR']]]
# PRG                       [[3, ['RGW', 'GWB', 'WBR']]]
# PRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWB', 'WBR'...
# PWB                                     [[1, ['WBR']]]
# PWG         [[5, ['WGR', 'GRP', 'RPW', 'PWB', 'WBR']]]
# PWR         [[5, ['WRG', 'RGP', 'GPW', 'PWB', 'WBR']]]
# RBG                [[4, ['BGP', 'GPW', 'PWB', 'WBR']]]
# RBP                [[4, ['BPG', 'PGW', 'GWB', 'WBR']]]
# RBW  [[6, ['BWG', 'WGR', 'GRP', 'RPW', 'PWB', 'WBR'...
# RGB  [[6, ['GBP', 'BPR', 'PRG', 'RGW', 'GWB', 'WBR']]]
# RGP                       [[3, ['GPW', 'PWB', 'WBR']]]
# RGW                              [[2, ['GWB', 'WBR']]]
# RPB  [[6, ['PBG', 'BGR', 'GRP', 'RPW', 'PWB', 'WBR']]]
# RPG                       [[3, ['PGW', 'GWB', 'WBR']]]
# RPW                              [[2, ['PWB', 'WBR']]]
# RWB  [[5, ['WBG', 'BGP', 'GPW', 'PWB', 'WBR']], [5,...
# RWG  [[6, ['WGB', 'GBR', 'BRP', 'RPW', 'PWB', 'WBR']]]
# RWP  [[6, ['WPB', 'PBR', 'BRG', 'RGW', 'GWB', 'WBR']]]
# WBG                [[4, ['BGP', 'GPW', 'PWB', 'WBR']]]
# WBP                [[4, ['BPG', 'PGW', 'GWB', 'WBR']]]
# WBR                                                NaN
# WGB         [[5, ['GBR', 'BRP', 'RPW', 'PWB', 'WBR']]]
# WGP  [[6, ['GPB', 'PBR', 'BRG', 'RGW', 'GWB', 'WBR']]]
# WGR                [[4, ['GRP', 'RPW', 'PWB', 'WBR']]]
# WPB         [[5, ['PBR', 'BRG', 'RGW', 'GWB', 'WBR']]]
# WPG  [[6, ['PGB', 'GBR', 'BRP', 'RPW', 'PWB', 'WBR']]]
# WPR                [[4, ['PRG', 'RGW', 'GWB', 'WBR']]]
# WRB  [[5, ['RBG', 'BGP', 'GPW', 'PWB', 'WBR']], [5,...
# WRG                [[4, ['RGP', 'GPW', 'PWB', 'WBR']]]
# WRP                [[4, ['RPG', 'PGW', 'GWB', 'WBR']]]
#
#                                                    WGB  \
# BGP                [[4, ['GPR', 'PRW', 'RWG', 'WGB']]]
# BGR                [[4, ['GRP', 'RPW', 'PWG', 'WGB']]]
# BGW  [[6, ['GWP', 'WPB', 'PBR', 'BRW', 'RWG', 'WGB'...
# BPG  [[6, ['PGR', 'GRB', 'RBP', 'BPW', 'PWG', 'WGB']]]
# BPR                       [[3, ['PRW', 'RWG', 'WGB']]]
# BPW                              [[2, ['PWG', 'WGB']]]
# BRG  [[6, ['RGP', 'GPB', 'PBR', 'BRW', 'RWG', 'WGB']]]
# BRP                       [[3, ['RPW', 'PWG', 'WGB']]]
# BRW                              [[2, ['RWG', 'WGB']]]
# BWG  [[5, ['WGP', 'GPR', 'PRW', 'RWG', 'WGB']], [5,...
# BWP  [[6, ['WPG', 'PGB', 'GBR', 'BRW', 'RWG', 'WGB']]]
# BWR  [[6, ['WRG', 'RGB', 'GBP', 'BPW', 'PWG', 'WGB']]]
# GBP                       [[3, ['BPW', 'PWG', 'WGB']]]
# GBR                       [[3, ['BRW', 'RWG', 'WGB']]]
# GBW  [[7, ['BWP', 'WPG', 'PGB', 'GBR', 'BRW', 'RWG'...
# GPB                [[4, ['PBR', 'BRW', 'RWG', 'WGB']]]
# GPR                       [[3, ['PRW', 'RWG', 'WGB']]]
# GPW  [[6, ['PWB', 'WBR', 'BRP', 'RPW', 'PWG', 'WGB'...
# GRB                [[4, ['RBP', 'BPW', 'PWG', 'WGB']]]
# GRP                       [[3, ['RPW', 'PWG', 'WGB']]]
# GRW  [[6, ['RWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGB'...
# GWB  [[5, ['WBP', 'BPR', 'PRW', 'RWG', 'WGB']], [5,...
# GWP         [[5, ['WPB', 'PBR', 'BRW', 'RWG', 'WGB']]]
# GWR         [[5, ['WRB', 'RBP', 'BPW', 'PWG', 'WGB']]]
# PBG         [[5, ['BGR', 'GRP', 'RPW', 'PWG', 'WGB']]]
# PBR                       [[3, ['BRW', 'RWG', 'WGB']]]
# PBW  [[6, ['BWG', 'WGP', 'GPR', 'PRW', 'RWG', 'WGB'...
# PGB                [[4, ['GBR', 'BRW', 'RWG', 'WGB']]]
# PGR         [[5, ['GRB', 'RBP', 'BPW', 'PWG', 'WGB']]]
# PGW  [[6, ['GWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGB'...
# PRB  [[6, ['RBG', 'BGP', 'GPR', 'PRW', 'RWG', 'WGB']]]
# PRG         [[5, ['RGB', 'GBP', 'BPW', 'PWG', 'WGB']]]
# PRW                              [[2, ['RWG', 'WGB']]]
# PWB         [[5, ['WBR', 'BRP', 'RPW', 'PWG', 'WGB']]]
# PWG                                     [[1, ['WGB']]]
# PWR         [[5, ['WRB', 'RBP', 'BPW', 'PWG', 'WGB']]]
# RBG         [[5, ['BGP', 'GPR', 'PRW', 'RWG', 'WGB']]]
# RBP                       [[3, ['BPW', 'PWG', 'WGB']]]
# RBW  [[6, ['BWG', 'WGP', 'GPR', 'PRW', 'RWG', 'WGB'...
# RGB                [[4, ['GBP', 'BPW', 'PWG', 'WGB']]]
# RGP         [[5, ['GPB', 'PBR', 'BRW', 'RWG', 'WGB']]]
# RGW  [[6, ['GWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGB'...
# RPB  [[6, ['PBG', 'BGR', 'GRP', 'RPW', 'PWG', 'WGB']]]
# RPG         [[5, ['PGB', 'GBR', 'BRW', 'RWG', 'WGB']]]
# RPW                              [[2, ['PWG', 'WGB']]]
# RWB         [[5, ['WBP', 'BPR', 'PRW', 'RWG', 'WGB']]]
# RWG                                     [[1, ['WGB']]]
# RWP         [[5, ['WPB', 'PBR', 'BRW', 'RWG', 'WGB']]]
# WBG  [[5, ['BGP', 'GPR', 'PRW', 'RWG', 'WGB']], [5,...
# WBP                [[4, ['BPR', 'PRW', 'RWG', 'WGB']]]
# WBR                [[4, ['BRP', 'RPW', 'PWG', 'WGB']]]
# WGB                                                NaN
# WGP                [[4, ['GPR', 'PRW', 'RWG', 'WGB']]]
# WGR                [[4, ['GRP', 'RPW', 'PWG', 'WGB']]]
# WPB                [[4, ['PBR', 'BRW', 'RWG', 'WGB']]]
# WPG         [[5, ['PGB', 'GBR', 'BRW', 'RWG', 'WGB']]]
# WPR  [[6, ['PRG', 'RGB', 'GBP', 'BPW', 'PWG', 'WGB']]]
# WRB                [[4, ['RBP', 'BPW', 'PWG', 'WGB']]]
# WRG         [[5, ['RGB', 'GBP', 'BPW', 'PWG', 'WGB']]]
# WRP  [[6, ['RPG', 'PGB', 'GBR', 'BRW', 'RWG', 'WGB']]]
#
#                                                    WGP  \
# BGP                [[4, ['GPR', 'PRW', 'RWG', 'WGP']]]
# BGR         [[5, ['GRP', 'RPB', 'PBW', 'BWG', 'WGP']]]
# BGW  [[6, ['GWP', 'WPB', 'PBR', 'BRW', 'RWG', 'WGP'...
# BPG         [[5, ['PGR', 'GRB', 'RBW', 'BWG', 'WGP']]]
# BPR                       [[3, ['PRW', 'RWG', 'WGP']]]
# BPW  [[6, ['PWG', 'WGB', 'GBR', 'BRW', 'RWG', 'WGP'...
# BRG         [[5, ['RGP', 'GPB', 'PBW', 'BWG', 'WGP']]]
# BRP  [[6, ['RPG', 'PGB', 'GBR', 'BRW', 'RWG', 'WGP']]]
# BRW                              [[2, ['RWG', 'WGP']]]
# BWG                                     [[1, ['WGP']]]
# BWP         [[5, ['WPR', 'PRB', 'RBW', 'BWG', 'WGP']]]
# BWR         [[5, ['WRP', 'RPB', 'PBW', 'BWG', 'WGP']]]
# GBP                [[4, ['BPR', 'PRW', 'RWG', 'WGP']]]
# GBR                       [[3, ['BRW', 'RWG', 'WGP']]]
# GBW  [[6, ['BWP', 'WPR', 'PRB', 'RBW', 'BWG', 'WGP'...
# GPB                       [[3, ['PBW', 'BWG', 'WGP']]]
# GPR                       [[3, ['PRW', 'RWG', 'WGP']]]
# GPW  [[7, ['PWB', 'WBG', 'BGP', 'GPR', 'PRW', 'RWG'...
# GRB                       [[3, ['RBW', 'BWG', 'WGP']]]
# GRP                [[4, ['RPB', 'PBW', 'BWG', 'WGP']]]
# GRW  [[6, ['RWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGP'...
# GWB         [[5, ['WBP', 'BPR', 'PRW', 'RWG', 'WGP']]]
# GWP  [[5, ['WPB', 'PBR', 'BRW', 'RWG', 'WGP']], [5,...
# GWR         [[5, ['WRP', 'RPB', 'PBW', 'BWG', 'WGP']]]
# PBG  [[6, ['BGR', 'GRP', 'RPB', 'PBW', 'BWG', 'WGP']]]
# PBR                       [[3, ['BRW', 'RWG', 'WGP']]]
# PBW                              [[2, ['BWG', 'WGP']]]
# PGB                [[4, ['GBR', 'BRW', 'RWG', 'WGP']]]
# PGR                [[4, ['GRB', 'RBW', 'BWG', 'WGP']]]
# PGW  [[6, ['GWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGP'...
# PRB                       [[3, ['RBW', 'BWG', 'WGP']]]
# PRG  [[6, ['RGB', 'GBP', 'BPR', 'PRW', 'RWG', 'WGP']]]
# PRW                              [[2, ['RWG', 'WGP']]]
# PWB  [[6, ['WBG', 'BGP', 'GPR', 'PRW', 'RWG', 'WGP']]]
# PWG  [[5, ['WGB', 'GBR', 'BRW', 'RWG', 'WGP']], [5,...
# PWR  [[6, ['WRG', 'RGP', 'GPB', 'PBW', 'BWG', 'WGP']]]
# RBG         [[5, ['BGP', 'GPR', 'PRW', 'RWG', 'WGP']]]
# RBP  [[6, ['BPG', 'PGR', 'GRB', 'RBW', 'BWG', 'WGP']]]
# RBW                              [[2, ['BWG', 'WGP']]]
# RGB         [[5, ['GBP', 'BPR', 'PRW', 'RWG', 'WGP']]]
# RGP                [[4, ['GPB', 'PBW', 'BWG', 'WGP']]]
# RGW  [[6, ['GWB', 'WBP', 'BPR', 'PRW', 'RWG', 'WGP'...
# RPB                       [[3, ['PBW', 'BWG', 'WGP']]]
# RPG         [[5, ['PGB', 'GBR', 'BRW', 'RWG', 'WGP']]]
# RPW  [[6, ['PWG', 'WGB', 'GBR', 'BRW', 'RWG', 'WGP'...
# RWB         [[5, ['WBP', 'BPR', 'PRW', 'RWG', 'WGP']]]
# RWG                                     [[1, ['WGP']]]
# RWP         [[5, ['WPB', 'PBR', 'BRW', 'RWG', 'WGP']]]
# WBG         [[5, ['BGP', 'GPR', 'PRW', 'RWG', 'WGP']]]
# WBP                [[4, ['BPR', 'PRW', 'RWG', 'WGP']]]
# WBR  [[6, ['BRG', 'RGP', 'GPB', 'PBW', 'BWG', 'WGP']]]
# WGB                [[4, ['GBR', 'BRW', 'RWG', 'WGP']]]
# WGP                                                NaN
# WGR                [[4, ['GRB', 'RBW', 'BWG', 'WGP']]]
# WPB                [[4, ['PBR', 'BRW', 'RWG', 'WGP']]]
# WPG  [[5, ['PGB', 'GBR', 'BRW', 'RWG', 'WGP']], [5,...
# WPR                [[4, ['PRB', 'RBW', 'BWG', 'WGP']]]
# WRB  [[6, ['RBG', 'BGP', 'GPR', 'PRW', 'RWG', 'WGP']]]
# WRG         [[5, ['RGP', 'GPB', 'PBW', 'BWG', 'WGP']]]
# WRP                [[4, ['RPB', 'PBW', 'BWG', 'WGP']]]
#
#                                                    WGR  \
# BGP         [[5, ['GPR', 'PRB', 'RBW', 'BWG', 'WGR']]]
# BGR                [[4, ['GRP', 'RPW', 'PWG', 'WGR']]]
# BGW  [[6, ['GWP', 'WPR', 'PRB', 'RBW', 'BWG', 'WGR'...
# BPG         [[5, ['PGR', 'GRB', 'RBW', 'BWG', 'WGR']]]
# BPR  [[6, ['PRG', 'RGB', 'GBP', 'BPW', 'PWG', 'WGR']]]
# BPW                              [[2, ['PWG', 'WGR']]]
# BRG         [[5, ['RGP', 'GPB', 'PBW', 'BWG', 'WGR']]]
# BRP                       [[3, ['RPW', 'PWG', 'WGR']]]
# BRW  [[6, ['RWG', 'WGB', 'GBP', 'BPW', 'PWG', 'WGR'...
# BWG                                     [[1, ['WGR']]]
# BWP         [[5, ['WPR', 'PRB', 'RBW', 'BWG', 'WGR']]]
# BWR         [[5, ['WRP', 'RPB', 'PBW', 'BWG', 'WGR']]]
# GBP                       [[3, ['BPW', 'PWG', 'WGR']]]
# GBR                [[4, ['BRP', 'RPW', 'PWG', 'WGR']]]
# GBW  [[6, ['BWP', 'WPR', 'PRB', 'RBW', 'BWG', 'WGR'...
# GPB                       [[3, ['PBW', 'BWG', 'WGR']]]
# GPR                [[4, ['PRB', 'RBW', 'BWG', 'WGR']]]
# GPW  [[6, ['PWB', 'WBR', 'BRP', 'RPW', 'PWG', 'WGR'...
# GRB                       [[3, ['RBW', 'BWG', 'WGR']]]
# GRP                       [[3, ['RPW', 'PWG', 'WGR']]]
# GRW  [[7, ['RWB', 'WBG', 'BGR', 'GRP', 'RPW', 'PWG'...
# GWB         [[5, ['WBR', 'BRP', 'RPW', 'PWG', 'WGR']]]
# GWP         [[5, ['WPR', 'PRB', 'RBW', 'BWG', 'WGR']]]
# GWR  [[5, ['WRB', 'RBP', 'BPW', 'PWG', 'WGR']], [5,...
# PBG         [[5, ['BGR', 'GRP', 'RPW', 'PWG', 'WGR']]]
# PBR  [[6, ['BRG', 'RGP', 'GPB', 'PBW', 'BWG', 'WGR']]]
# PBW                              [[2, ['BWG', 'WGR']]]
# PGB         [[5, ['GBR', 'BRP', 'RPW', 'PWG', 'WGR']]]
# ...
# PGR                       [[3, ['GRW', 'RWP', 'WPG']]]
# PGW  [[7, ['GWB', 'WBP', 'BPG', 'PGR', 'GRW', 'RWP'...
# PRB                       [[3, ['RBW', 'BWP', 'WPG']]]
# PRG                [[4, ['RGB', 'GBW', 'BWP', 'WPG']]]
# PRW  [[6, ['RWB', 'WBG', 'BGR', 'GRW', 'RWP', 'WPG'...
# PWB         [[5, ['WBG', 'BGR', 'GRW', 'RWP', 'WPG']]]
# PWG  [[5, ['WGB', 'GBR', 'BRW', 'RWP', 'WPG']], [5,...
# PWR         [[5, ['WRG', 'RGB', 'GBW', 'BWP', 'WPG']]]
# RBG  [[6, ['BGP', 'GPR', 'PRB', 'RBW', 'BWP', 'WPG']]]
# RBP         [[5, ['BPG', 'PGR', 'GRW', 'RWP', 'WPG']]]
# RBW                              [[2, ['BWP', 'WPG']]]
# RGB                       [[3, ['GBW', 'BWP', 'WPG']]]
# RGP         [[5, ['GPB', 'PBR', 'BRW', 'RWP', 'WPG']]]
# RGW  [[6, ['GWP', 'WPB', 'PBR', 'BRW', 'RWP', 'WPG'...
# RPB         [[5, ['PBG', 'BGR', 'GRW', 'RWP', 'WPG']]]
# RPG                [[4, ['PGB', 'GBW', 'BWP', 'WPG']]]
# RPW  [[6, ['PWB', 'WBG', 'BGR', 'GRW', 'RWP', 'WPG'...
# RWB         [[5, ['WBG', 'BGR', 'GRW', 'RWP', 'WPG']]]
# RWG         [[5, ['WGB', 'GBR', 'BRW', 'RWP', 'WPG']]]
# RWP                                     [[1, ['WPG']]]
# WBG                [[4, ['BGR', 'GRW', 'RWP', 'WPG']]]
# WBP         [[5, ['BPG', 'PGR', 'GRW', 'RWP', 'WPG']]]
# WBR  [[6, ['BRP', 'RPG', 'PGB', 'GBW', 'BWP', 'WPG']]]
# WGB                [[4, ['GBR', 'BRW', 'RWP', 'WPG']]]
# WGP  [[5, ['GPB', 'PBR', 'BRW', 'RWP', 'WPG']], [5,...
# WGR                [[4, ['GRB', 'RBW', 'BWP', 'WPG']]]
# WPB                [[4, ['PBR', 'BRW', 'RWP', 'WPG']]]
# WPG                                                NaN
# WPR                [[4, ['PRB', 'RBW', 'BWP', 'WPG']]]
# WRB  [[6, ['RBP', 'BPG', 'PGR', 'GRW', 'RWP', 'WPG']]]
# WRG                [[4, ['RGB', 'GBW', 'BWP', 'WPG']]]
# WRP         [[5, ['RPG', 'PGB', 'GBW', 'BWP', 'WPG']]]
#
#                                                    WPR  \
# BGP         [[5, ['GPR', 'PRB', 'RBW', 'BWP', 'WPR']]]
# BGR  [[6, ['GRP', 'RPB', 'PBG', 'BGW', 'GWP', 'WPR']]]
# BGW                              [[2, ['GWP', 'WPR']]]
# BPG         [[5, ['PGR', 'GRB', 'RBW', 'BWP', 'WPR']]]
# BPR                [[4, ['PRG', 'RGW', 'GWP', 'WPR']]]
# BPW  [[6, ['PWG', 'WGR', 'GRB', 'RBW', 'BWP', 'WPR'...
# BRG                       [[3, ['RGW', 'GWP', 'WPR']]]
# BRP         [[5, ['RPG', 'PGB', 'GBW', 'BWP', 'WPR']]]
# BRW  [[6, ['RWP', 'WPB', 'PBG', 'BGW', 'GWP', 'WPR'...
# BWG         [[5, ['WGR', 'GRB', 'RBW', 'BWP', 'WPR']]]
# BWP                                     [[1, ['WPR']]]
# BWR         [[5, ['WRG', 'RGB', 'GBW', 'BWP', 'WPR']]]
# GBP         [[5, ['BPR', 'PRG', 'RGW', 'GWP', 'WPR']]]
# GBR  [[6, ['BRP', 'RPG', 'PGB', 'GBW', 'BWP', 'WPR']]]
# GBW                              [[2, ['BWP', 'WPR']]]
# GPB         [[5, ['PBR', 'BRG', 'RGW', 'GWP', 'WPR']]]
# GPR                [[4, ['PRB', 'RBW', 'BWP', 'WPR']]]
# GPW  [[6, ['PWB', 'WBR', 'BRG', 'RGW', 'GWP', 'WPR'...
# GRB                       [[3, ['RBW', 'BWP', 'WPR']]]
# GRP         [[5, ['RPB', 'PBG', 'BGW', 'GWP', 'WPR']]]
# GRW  [[6, ['RWP', 'WPB', 'PBG', 'BGW', 'GWP', 'WPR'...
# GWB         [[5, ['WBR', 'BRG', 'RGW', 'GWP', 'WPR']]]
# GWP                                     [[1, ['WPR']]]
# GWR         [[5, ['WRB', 'RBG', 'BGW', 'GWP', 'WPR']]]
# PBG                       [[3, ['BGW', 'GWP', 'WPR']]]
# PBR                [[4, ['BRG', 'RGW', 'GWP', 'WPR']]]
# PBW  [[6, ['BWG', 'WGR', 'GRB', 'RBW', 'BWP', 'WPR'...
# PGB                       [[3, ['GBW', 'BWP', 'WPR']]]
# PGR                [[4, ['GRB', 'RBW', 'BWP', 'WPR']]]
# PGW  [[6, ['GWB', 'WBR', 'BRG', 'RGW', 'GWP', 'WPR'...
# PRB                       [[3, ['RBW', 'BWP', 'WPR']]]
# PRG                       [[3, ['RGW', 'GWP', 'WPR']]]
# PRW  [[7, ['RWB', 'WBP', 'BPR', 'PRG', 'RGW', 'GWP'...
# PWB         [[5, ['WBR', 'BRG', 'RGW', 'GWP', 'WPR']]]
# PWG         [[5, ['WGR', 'GRB', 'RBW', 'BWP', 'WPR']]]
# PWR  [[5, ['WRB', 'RBG', 'BGW', 'GWP', 'WPR']], [5,...
# RBG                       [[3, ['BGW', 'GWP', 'WPR']]]
# RBP  [[6, ['BPG', 'PGR', 'GRB', 'RBW', 'BWP', 'WPR']]]
# RBW                              [[2, ['BWP', 'WPR']]]
# RGB                       [[3, ['GBW', 'BWP', 'WPR']]]
# RGP  [[6, ['GPB', 'PBR', 'BRG', 'RGW', 'GWP', 'WPR']]]
# RGW                              [[2, ['GWP', 'WPR']]]
# RPB                [[4, ['PBG', 'BGW', 'GWP', 'WPR']]]
# RPG                [[4, ['PGB', 'GBW', 'BWP', 'WPR']]]
# RPW  [[6, ['PWB', 'WBR', 'BRG', 'RGW', 'GWP', 'WPR'...
# RWB  [[6, ['WBP', 'BPR', 'PRG', 'RGW', 'GWP', 'WPR']]]
# RWG  [[6, ['WGP', 'GPR', 'PRB', 'RBW', 'BWP', 'WPR']]]
# RWP  [[5, ['WPB', 'PBG', 'BGW', 'GWP', 'WPR']], [5,...
# WBG  [[6, ['BGP', 'GPR', 'PRB', 'RBW', 'BWP', 'WPR']]]
# WBP         [[5, ['BPR', 'PRG', 'RGW', 'GWP', 'WPR']]]
# WBR                [[4, ['BRG', 'RGW', 'GWP', 'WPR']]]
# WGB  [[6, ['GBP', 'BPR', 'PRG', 'RGW', 'GWP', 'WPR']]]
# WGP         [[5, ['GPR', 'PRB', 'RBW', 'BWP', 'WPR']]]
# WGR                [[4, ['GRB', 'RBW', 'BWP', 'WPR']]]
# WPB                [[4, ['PBG', 'BGW', 'GWP', 'WPR']]]
# WPG                [[4, ['PGB', 'GBW', 'BWP', 'WPR']]]
# WPR                                                NaN
# WRB                [[4, ['RBG', 'BGW', 'GWP', 'WPR']]]
# WRG                [[4, ['RGB', 'GBW', 'BWP', 'WPR']]]
# WRP  [[5, ['RPB', 'PBG', 'BGW', 'GWP', 'WPR']], [5,...
#
#                                                    WRB  \
# BGP                       [[3, ['GPW', 'PWR', 'WRB']]]
# BGR  [[6, ['GRP', 'RPB', 'PBG', 'BGW', 'GWR', 'WRB']]]
# BGW                              [[2, ['GWR', 'WRB']]]
# BPG                       [[3, ['PGW', 'GWR', 'WRB']]]
# BPR  [[6, ['PRG', 'RGB', 'GBP', 'BPW', 'PWR', 'WRB']]]
# BPW                              [[2, ['PWR', 'WRB']]]
# BRG                [[4, ['RGP', 'GPW', 'PWR', 'WRB']]]
# BRP                [[4, ['RPG', 'PGW', 'GWR', 'WRB']]]
# BRW  [[6, ['RWG', 'WGB', 'GBP', 'BPW', 'PWR', 'WRB'...
# BWG  [[6, ['WGR', 'GRB', 'RBP', 'BPW', 'PWR', 'WRB']]]
# BWP  [[6, ['WPR', 'PRB', 'RBG', 'BGW', 'GWR', 'WRB']]]
# BWR  [[5, ['WRG', 'RGP', 'GPW', 'PWR', 'WRB']], [5,...
# GBP                       [[3, ['BPW', 'PWR', 'WRB']]]
# GBR         [[5, ['BRP', 'RPG', 'PGW', 'GWR', 'WRB']]]
# GBW  [[6, ['BWR', 'WRG', 'RGP', 'GPW', 'PWR', 'WRB'...
# GPB  [[6, ['PBR', 'BRG', 'RGP', 'GPW', 'PWR', 'WRB']]]
# GPR         [[5, ['PRB', 'RBG', 'BGW', 'GWR', 'WRB']]]
# GPW                              [[2, ['PWR', 'WRB']]]
# GRB                [[4, ['RBP', 'BPW', 'PWR', 'WRB']]]
# GRP         [[5, ['RPB', 'PBG', 'BGW', 'GWR', 'WRB']]]
# GRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRB'...
# GWB         [[5, ['WBP', 'BPG', 'PGW', 'GWR', 'WRB']]]
# GWP         [[5, ['WPB', 'PBG', 'BGW', 'GWR', 'WRB']]]
# GWR                                     [[1, ['WRB']]]
# PBG                       [[3, ['BGW', 'GWR', 'WRB']]]
# PBR         [[5, ['BRG', 'RGP', 'GPW', 'PWR', 'WRB']]]
# PBW  [[6, ['BWR', 'WRG', 'RGP', 'GPW', 'PWR', 'WRB'...
# PGB  [[6, ['GBR', 'BRP', 'RPG', 'PGW', 'GWR', 'WRB']]]
# PGR         [[5, ['GRB', 'RBP', 'BPW', 'PWR', 'WRB']]]
# PGW                              [[2, ['GWR', 'WRB']]]
# PRB                [[4, ['RBG', 'BGW', 'GWR', 'WRB']]]
# PRG         [[5, ['RGB', 'GBP', 'BPW', 'PWR', 'WRB']]]
# PRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRB'...
# PWB         [[5, ['WBG', 'BGP', 'GPW', 'PWR', 'WRB']]]
# PWG         [[5, ['WGB', 'GBP', 'BPW', 'PWR', 'WRB']]]
# PWR                                     [[1, ['WRB']]]
# RBG                       [[3, ['BGW', 'GWR', 'WRB']]]
# RBP                       [[3, ['BPW', 'PWR', 'WRB']]]
# RBW  [[7, ['BWG', 'WGR', 'GRB', 'RBP', 'BPW', 'PWR'...
# RGB                [[4, ['GBP', 'BPW', 'PWR', 'WRB']]]
# RGP                       [[3, ['GPW', 'PWR', 'WRB']]]
# RGW  [[6, ['GWB', 'WBP', 'BPG', 'PGW', 'GWR', 'WRB'...
# RPB                [[4, ['PBG', 'BGW', 'GWR', 'WRB']]]
# RPG                       [[3, ['PGW', 'GWR', 'WRB']]]
# RPW  [[6, ['PWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRB'...
# RWB  [[5, ['WBG', 'BGP', 'GPW', 'PWR', 'WRB']], [5,...
# RWG         [[5, ['WGB', 'GBP', 'BPW', 'PWR', 'WRB']]]
# RWP         [[5, ['WPB', 'PBG', 'BGW', 'GWR', 'WRB']]]
# WBG                [[4, ['BGP', 'GPW', 'PWR', 'WRB']]]
# WBP                [[4, ['BPG', 'PGW', 'GWR', 'WRB']]]
# WBR  [[5, ['BRG', 'RGP', 'GPW', 'PWR', 'WRB']], [5,...
# WGB                [[4, ['GBP', 'BPW', 'PWR', 'WRB']]]
# WGP  [[6, ['GPR', 'PRB', 'RBG', 'BGW', 'GWR', 'WRB']]]
# WGR         [[5, ['GRB', 'RBP', 'BPW', 'PWR', 'WRB']]]
# WPB                [[4, ['PBG', 'BGW', 'GWR', 'WRB']]]
# WPG  [[6, ['PGR', 'GRB', 'RBP', 'BPW', 'PWR', 'WRB']]]
# WPR         [[5, ['PRB', 'RBG', 'BGW', 'GWR', 'WRB']]]
# WRB                                                NaN
# WRG                [[4, ['RGP', 'GPW', 'PWR', 'WRB']]]
# WRP                [[4, ['RPG', 'PGW', 'GWR', 'WRB']]]
#
#                                                    WRG  \
# BGP                       [[3, ['GPW', 'PWR', 'WRG']]]
# BGR         [[5, ['GRP', 'RPB', 'PBW', 'BWR', 'WRG']]]
# BGW  [[6, ['GWR', 'WRB', 'RBP', 'BPW', 'PWR', 'WRG'...
# BPG  [[6, ['PGR', 'GRB', 'RBP', 'BPW', 'PWR', 'WRG']]]
# BPR         [[5, ['PRG', 'RGB', 'GBW', 'BWR', 'WRG']]]
# BPW                              [[2, ['PWR', 'WRG']]]
# BRG                [[4, ['RGP', 'GPW', 'PWR', 'WRG']]]
# BRP         [[5, ['RPG', 'PGB', 'GBW', 'BWR', 'WRG']]]
# BRW  [[6, ['RWG', 'WGB', 'GBP', 'BPW', 'PWR', 'WRG'...
# BWG         [[5, ['WGP', 'GPB', 'PBW', 'BWR', 'WRG']]]
# BWP         [[5, ['WPG', 'PGB', 'GBW', 'BWR', 'WRG']]]
# BWR                                     [[1, ['WRG']]]
# GBP                       [[3, ['BPW', 'PWR', 'WRG']]]
# GBR  [[6, ['BRP', 'RPG', 'PGB', 'GBW', 'BWR', 'WRG']]]
# GBW                              [[2, ['BWR', 'WRG']]]
# GPB                       [[3, ['PBW', 'BWR', 'WRG']]]
# GPR  [[6, ['PRB', 'RBG', 'BGP', 'GPW', 'PWR', 'WRG']]]
# GPW                              [[2, ['PWR', 'WRG']]]
# GRB                [[4, ['RBP', 'BPW', 'PWR', 'WRG']]]
# GRP                [[4, ['RPB', 'PBW', 'BWR', 'WRG']]]
# GRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRG'...
# GWB  [[6, ['WBR', 'BRG', 'RGP', 'GPW', 'PWR', 'WRG']]]
# GWP  [[6, ['WPR', 'PRG', 'RGB', 'GBW', 'BWR', 'WRG']]]
# GWR  [[5, ['WRB', 'RBP', 'BPW', 'PWR', 'WRG']], [5,...
# PBG  [[6, ['BGR', 'GRP', 'RPB', 'PBW', 'BWR', 'WRG']]]
# PBR         [[5, ['BRG', 'RGP', 'GPW', 'PWR', 'WRG']]]
# PBW                              [[2, ['BWR', 'WRG']]]
# PGB                       [[3, ['GBW', 'BWR', 'WRG']]]
# PGR         [[5, ['GRB', 'RBP', 'BPW', 'PWR', 'WRG']]]
# PGW  [[6, ['GWR', 'WRB', 'RBP', 'BPW', 'PWR', 'WRG'...
# PRB         [[5, ['RBG', 'BGP', 'GPW', 'PWR', 'WRG']]]
# PRG                [[4, ['RGB', 'GBW', 'BWR', 'WRG']]]
# PRW  [[6, ['RWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRG'...
# PWB         [[5, ['WBG', 'BGP', 'GPW', 'PWR', 'WRG']]]
# PWG         [[5, ['WGB', 'GBP', 'BPW', 'PWR', 'WRG']]]
# PWR                                     [[1, ['WRG']]]
# RBG                [[4, ['BGP', 'GPW', 'PWR', 'WRG']]]
# RBP                       [[3, ['BPW', 'PWR', 'WRG']]]
# RBW  [[6, ['BWG', 'WGP', 'GPB', 'PBW', 'BWR', 'WRG'...
# RGB                       [[3, ['GBW', 'BWR', 'WRG']]]
# RGP                       [[3, ['GPW', 'PWR', 'WRG']]]
# RGW  [[7, ['GWB', 'WBR', 'BRG', 'RGP', 'GPW', 'PWR'...
# RPB                       [[3, ['PBW', 'BWR', 'WRG']]]
# RPG                [[4, ['PGB', 'GBW', 'BWR', 'WRG']]]
# RPW  [[6, ['PWB', 'WBG', 'BGP', 'GPW', 'PWR', 'WRG'...
# RWB         [[5, ['WBG', 'BGP', 'GPW', 'PWR', 'WRG']]]
# RWG  [[5, ['WGB', 'GBP', 'BPW', 'PWR', 'WRG']], [5,...
# RWP         [[5, ['WPG', 'PGB', 'GBW', 'BWR', 'WRG']]]
# WBG                [[4, ['BGP', 'GPW', 'PWR', 'WRG']]]
# WBP  [[6, ['BPR', 'PRG', 'RGB', 'GBW', 'BWR', 'WRG']]]
# WBR         [[5, ['BRG', 'RGP', 'GPW', 'PWR', 'WRG']]]
# WGB                [[4, ['GBP', 'BPW', 'PWR', 'WRG']]]
# WGP                [[4, ['GPB', 'PBW', 'BWR', 'WRG']]]
# WGR  [[5, ['GRB', 'RBP', 'BPW', 'PWR', 'WRG']], [5,...
# WPB  [[6, ['PBR', 'BRG', 'RGP', 'GPW', 'PWR', 'WRG']]]
# WPG                [[4, ['PGB', 'GBW', 'BWR', 'WRG']]]
# WPR         [[5, ['PRG', 'RGB', 'GBW', 'BWR', 'WRG']]]
# WRB                [[4, ['RBP', 'BPW', 'PWR', 'WRG']]]
# WRG                                                NaN
# WRP                [[4, ['RPB', 'PBW', 'BWR', 'WRG']]]
#
#                                                    WRP
# BGP  [[6, ['GPR', 'PRB', 'RBG', 'BGW', 'GWR', 'WRP']]]
# BGR         [[5, ['GRP', 'RPB', 'PBW', 'BWR', 'WRP']]]
# BGW                              [[2, ['GWR', 'WRP']]]
# BPG                       [[3, ['PGW', 'GWR', 'WRP']]]
# BPR         [[5, ['PRG', 'RGB', 'GBW', 'BWR', 'WRP']]]
# BPW  [[6, ['PWR', 'WRB', 'RBG', 'BGW', 'GWR', 'WRP'...
# BRG         [[5, ['RGP', 'GPB', 'PBW', 'BWR', 'WRP']]]
# BRP                [[4, ['RPG', 'PGW', 'GWR', 'WRP']]]
# BRW  [[6, ['RWG', 'WGP', 'GPB', 'PBW', 'BWR', 'WRP'...
# BWG         [[5, ['WGP', 'GPB', 'PBW', 'BWR', 'WRP']]]
# BWP         [[5, ['WPG', 'PGB', 'GBW', 'BWR', 'WRP']]]
# BWR                                     [[1, ['WRP']]]
# GBP  [[6, ['BPR', 'PRG', 'RGB', 'GBW', 'BWR', 'WRP']]]
# GBR         [[5, ['BRP', 'RPG', 'PGW', 'GWR', 'WRP']]]
# GBW                              [[2, ['BWR', 'WRP']]]
# GPB                       [[3, ['PBW', 'BWR', 'WRP']]]
# GPR         [[5, ['PRB', 'RBG', 'BGW', 'GWR', 'WRP']]]
# GPW  [[6, ['PWR', 'WRB', 'RBG', 'BGW', 'GWR', 'WRP'...
# GRB         [[5, ['RBP', 'BPG', 'PGW', 'GWR', 'WRP']]]
# GRP                [[4, ['RPB', 'PBW', 'BWR', 'WRP']]]
# GRW  [[6, ['RWB', 'WBP', 'BPG', 'PGW', 'GWR', 'WRP'...
# GWB         [[5, ['WBP', 'BPG', 'PGW', 'GWR', 'WRP']]]
# GWP         [[5, ['WPB', 'PBG', 'BGW', 'GWR', 'WRP']]]
# GWR                                     [[1, ['WRP']]]
# PBG                       [[3, ['BGW', 'GWR', 'WRP']]]
# PBR  [[6, ['BRG', 'RGP', 'GPB', 'PBW', 'BWR', 'WRP']]]
# PBW                              [[2, ['BWR', 'WRP']]]
# PGB                       [[3, ['GBW', 'BWR', 'WRP']]]
# PGR  [[6, ['GRB', 'RBP', 'BPG', 'PGW', 'GWR', 'WRP']]]
# PGW                              [[2, ['GWR', 'WRP']]]
# PRB                [[4, ['RBG', 'BGW', 'GWR', 'WRP']]]
# PRG                [[4, ['RGB', 'GBW', 'BWR', 'WRP']]]
# PRW  [[6, ['RWB', 'WBP', 'BPG', 'PGW', 'GWR', 'WRP'...
# PWB  [[6, ['WBR', 'BRP', 'RPG', 'PGW', 'GWR', 'WRP']]]
# PWG  [[6, ['WGR', 'GRP', 'RPB', 'PBW', 'BWR', 'WRP']]]
# PWR  [[5, ['WRB', 'RBG', 'BGW', 'GWR', 'WRP']], [5,...
# RBG                       [[3, ['BGW', 'GWR', 'WRP']]]
# RBP                [[4, ['BPG', 'PGW', 'GWR', 'WRP']]]
# RBW  [[6, ['BWG', 'WGP', 'GPB', 'PBW', 'BWR', 'WRP'...
# RGB                       [[3, ['GBW', 'BWR', 'WRP']]]
# RGP                [[4, ['GPB', 'PBW', 'BWR', 'WRP']]]
# RGW  [[6, ['GWB', 'WBP', 'BPG', 'PGW', 'GWR', 'WRP'...
# RPB                       [[3, ['PBW', 'BWR', 'WRP']]]
# RPG                       [[3, ['PGW', 'GWR', 'WRP']]]
# RPW  [[7, ['PWB', 'WBR', 'BRP', 'RPG', 'PGW', 'GWR'...
# RWB         [[5, ['WBP', 'BPG', 'PGW', 'GWR', 'WRP']]]
# RWG         [[5, ['WGP', 'GPB', 'PBW', 'BWR', 'WRP']]]
# RWP  [[5, ['WPB', 'PBG', 'BGW', 'GWR', 'WRP']], [5,...
# WBG  [[6, ['BGR', 'GRP', 'RPB', 'PBW', 'BWR', 'WRP']]]
# WBP                [[4, ['BPG', 'PGW', 'GWR', 'WRP']]]
# WBR         [[5, ['BRP', 'RPG', 'PGW', 'GWR', 'WRP']]]
# WGB  [[6, ['GBR', 'BRP', 'RPG', 'PGW', 'GWR', 'WRP']]]
# WGP                [[4, ['GPB', 'PBW', 'BWR', 'WRP']]]
# WGR         [[5, ['GRP', 'RPB', 'PBW', 'BWR', 'WRP']]]
# WPB                [[4, ['PBG', 'BGW', 'GWR', 'WRP']]]
# WPG                [[4, ['PGB', 'GBW', 'BWR', 'WRP']]]
# WPR  [[5, ['PRB', 'RBG', 'BGW', 'GWR', 'WRP']], [5,...
# WRB                [[4, ['RBG', 'BGW', 'GWR', 'WRP']]]
# WRG                [[4, ['RGB', 'GBW', 'BWR', 'WRP']]]
# WRP                                                NaN
#
# [60 rows x 84 columns]

# %% [markdown]
# #### One Final Note
# It will be helpful to convert these results into a more usable form. The following basically decodes the solutions into directions. The result will help instruct the Aphelios player on the order in which to deplete their weapons to achieve the desired end state.

# %%
methods = solutions.copy()

for i in range(methods.shape[0]): # iterate through rows
   for j in range(methods.shape[1]): # iterate through columns
      solutions_set = (methods.iloc[i,j]) # pull the given set of solutions (often only 1 or 2, sometimes 3)
      if solutions_set == "": # Check if it's an empty solution.
        if len(solutions_set[0][1][-1])!=5: # Check if the final node is associational or base.

        # If base...
        # Iterate through the set of solutions, iterate through the nodes in that solution,
        #   gather the last letters of each of the nodes compress them into a string,
        #   then merge them back into a list of methods.
          method = [''.join([node[-1] for node in solution[1]]) for solution in solutions_set]
          methods.iloc[i,j] = method

        # If associational...
        # Do the same, except ignore the associational node at the end (i.e., [0:(len(solution[1])-1)]).
        else:
          method = [''.join([node[-1] for node in solution[1][0:(len(solution[1])-1)]]) for solution in solutions_set]
          methods.iloc[i,j] = method

# %%
print(methods)
methods.to_csv("Aphelios_Methods.csv")
# Out:
#                           BGP                       BGR  \
# BGP                       NaN                    [WBGR]
# BGR                    [WBGP]                       NaN
# BGW                    [RBGP]                    [PBGR]
# BPG            [RWBGP, WRBGP]                   [RWBGR]
# BPR                    [WBGP]                    [WBGR]
# BPW                    [RBGP]                  [GRPBGR]
# BRG                   [PWBGP]            [PWBGR, WPBGR]
# BRP                    [WBGP]                    [WBGR]
# BRW                  [GPRBGP]                    [PBGR]
# BWG                   [PRBGP]                   [RPBGR]
# BWP                    [RBGP]                  [GRWBGR]
# BWR                  [GPWBGP]                    [PBGR]
# GBP            [RWBGP, WRBGP]                   [RWBGR]
# GBR                   [PWBGP]            [PWBGR, WPBGR]
# GBW                   [PRBGP]                   [RPBGR]
# GPB        [RGPWBGP, WGPRBGP]          [RWPBGR, WRPBGR]
# GPR                     [BGP]                    [WBGR]
# GPW                     [BGP]                     [BGR]
# GRB          [PWRBGP, WPRBGP]        [PGRWBGR, WGRPBGR]
# GRP                    [WBGP]                     [BGR]
# GRW                     [BGP]                     [BGR]
# GWB          [PRWBGP, RPWBGP]          [PRWBGR, RPWBGR]
# GWP                    [RBGP]                     [BGR]
# GWR                     [BGP]                    [PBGR]
# PBG            [RWBGP, WRBGP]                       [R]
# PBR                  [GPWBGP]                   [WPBGR]
# PBW                  [GPRBGP]                   [RPBGR]
# PGB          [RPWBGP, WPRBGP]  [RPWBGR, RWPBGR, WRPBGR]
# PGR                    [WBGP]                    [WBGR]
# PGW                    [RBGP]                   [RPBGR]
# PRB                      [GP]          [GPWBGR, GWPBGR]
# PRG                  [WPRBGP]                   [WPBGR]
# PRW                     [BGP]                     [BGR]
# PWB                      [GP]                      [GR]
# PWG                  [RPWBGP]                   [RPBGR]
# PWR                     [BGP]                  [GPWBGR]
# RBG                       [P]            [PWBGR, WPBGR]
# RBP                   [WRBGP]                  [GRWBGR]
# RBW                   [PRBGP]                  [GRPBGR]
# RGB  [PRWBGP, PWRBGP, WPRBGP]          [PRWBGR, WRPBGR]
# RGP                    [WBGP]                    [WBGR]
# RGW                   [PRBGP]                    [PBGR]
# RPB          [GRWBGP, GWRBGP]                      [GR]
# RPG                   [WRBGP]                  [WRPBGR]
# RPW                     [BGP]                     [BGR]
# RWB                      [GP]                      [GR]
# RWG                   [PRBGP]                  [PRWBGR]
# RWP                  [GRWBGP]                     [BGR]
# WBG                       [P]                       [R]
# WBP                   [RWBGP]                   [RWBGR]
# WBR                   [PWBGP]                   [PWBGR]
# WGB  [PRWBGP, PWRBGP, RPWBGP]  [PRWBGR, RPWBGR, RWPBGR]
# WGP                    [RBGP]                   [RWBGR]
# WGR                   [PWBGP]                    [PBGR]
# WPB          [GRWBGP, GWRBGP]                      [GR]
# WPG                   [RWBGP]                   [RWBGR]
# WPR                     [BGP]                  [GWPBGR]
# WRB                      [GP]          [GPWBGR, GWPBGR]
# WRG                   [PWBGP]                   [PWBGR]
# WRP                  [GWRBGP]                     [BGR]
#
#                           BGW                       BPG  \
# BGP                    [RBGW]            [RWBPG, WRBPG]
# BGR                    [PBGW]                    [WBPG]
# BGW                       NaN                    [RBPG]
# BPG                   [WRBGW]                       NaN
# BPR                  [GWPBGW]                    [WBPG]
# BPW                    [RBGW]                    [RBPG]
# BRG                   [WPBGW]                    [WBPG]
# BRP                  [GWRBGW]                   [GWBPG]
# BRW                    [PBGW]                  [PGRBPG]
# BWG            [PRBGW, RPBGW]                    [RBPG]
# BWP                    [RBGW]                   [GRBPG]
# BWR                    [PBGW]                  [PGWBPG]
# GBP                   [WRBGW]            [RWBPG, WRBPG]
# GBR                   [WPBGW]                  [PGWBPG]
# GBW            [PRBGW, RPBGW]                  [PGRBPG]
# GPB          [RWPBGW, WRPBGW]          [RGWBPG, WGRBPG]
# GPR                     [BGW]                    [WBPG]
# GPW                    [RBGW]                    [RBPG]
# GRB          [PWRBGW, WPRBGW]                      [PG]
# GRP                     [BGW]                  [WGRBPG]
# GRW                    [PBGW]                     [BPG]
# GWB        [PGWRBGW, RGWPBGW]                      [PG]
# GWP                     [BGW]                  [RGWBPG]
# GWR                     [BGW]                     [BPG]
# PBG                       [W]            [RWBPG, WRBPG]
# PBR                   [WPBGW]                   [GWBPG]
# PBW                   [RPBGW]                   [GRBPG]
# PGB  [RWPBGW, WPRBGW, WRPBGW]        [RPGWBPG, WPGRBPG]
# PGR                   [WPBGW]                     [BPG]
# PGW                    [RBGW]                     [BPG]
# PRB                      [GW]          [GWRBPG, WGRBPG]
# PRG                   [WPBGW]                    [WBPG]
# PRW                  [GPRBGW]                     [BPG]
# PWB          [GPRBGW, GRPBGW]          [GRWBPG, RGWBPG]
# PWG                   [RPBGW]                    [RBPG]
# PWR                     [BGW]                     [BPG]
# RBG                       [W]                   [WRBPG]
# RBP                   [WRBGW]                       [G]
# RBW                   [PRBGW]                   [GRBPG]
# RGB  [PWRBGW, WPRBGW, WRPBGW]          [PRWBPG, PWRBPG]
# RGP                   [WRBGW]                   [WRBPG]
# RGW                    [PBGW]                     [BPG]
# RPB                      [GW]  [GRWBPG, GWRBPG, WGRBPG]
# RPG                   [WRBGW]                    [WBPG]
# RPW                  [GRPBGW]                   [GRBPG]
# RWB          [GPRBGW, GRPBGW]                      [PG]
# RWG                   [PRBGW]                  [PRWBPG]
# RWP                     [BGW]                   [GRBPG]
# WBG            [PRBGW, RPBGW]                   [RWBPG]
# WBP                  [GWRBGW]                       [G]
# WBR                  [GWPBGW]                   [GWBPG]
# WGB          [PWRBGW, RWPBGW]          [PRWBPG, PWRBPG]
# WGP                    [RBGW]                   [RWBPG]
# WGR                    [PBGW]                     [BPG]
# WPB                      [GW]  [GRWBPG, GWRBPG, RGWBPG]
# WPG                  [RWPBGW]                    [RBPG]
# WPR                     [BGW]                   [GWBPG]
# WRB                      [GW]                      [PG]
# WRG                  [PWRBGW]                  [PWRBPG]
# WRP                     [BGW]                   [GWBPG]
#
#                           BPR                       BPW  \
# BGP                   [RWBPR]                   [WRBPW]
# BGR                    [WBPR]                  [PWGBPW]
# BGW                  [PRGBPR]                    [RBPW]
# BPG                    [WBPR]                    [RBPW]
# BPR                       NaN                    [GBPW]
# BPW                    [GBPR]                       NaN
# BRG                    [WBPR]                  [PWRBPW]
# BRP            [GWBPR, WGBPR]                   [WGBPW]
# BRW                    [GBPR]                    [GBPW]
# BWG                  [PRWBPR]                    [RBPW]
# BWP                   [RGBPR]            [GRBPW, RGBPW]
# BWR                    [GBPR]                    [GBPW]
# GBP                       [R]                       [W]
# GBR                   [WGBPR]                   [WGBPW]
# GBW                   [RGBPR]                   [RGBPW]
# GPB  [RGWBPR, RWGBPR, WRGBPR]  [RWGBPW, WGRBPW, WRGBPW]
# GPR                    [WBPR]                   [WGBPW]
# GPW                   [RGBPR]                    [RBPW]
# GRB          [PGWBPR, PWGBPR]                      [PW]
# GRP                   [WGBPR]                   [WGBPW]
# GRW                     [BPR]                  [PGRBPW]
# GWB                      [PR]          [PGRBPW, PRGBPW]
# GWP                   [RGBPR]                   [RGBPW]
# GWR                  [PGWBPR]                     [BPW]
# PBG                   [RWBPR]                   [WRBPW]
# PBR            [GWBPR, WGBPR]                   [WGBPW]
# PBW                   [RGBPR]            [GRBPW, RGBPW]
# PGB          [RWGBPR, WRGBPR]          [RWGBPW, WRGBPW]
# PGR                    [WBPR]                     [BPW]
# PGW                     [BPR]                    [RBPW]
# PRB        [GPRWBPR, WPRGBPR]          [GWRBPW, WGRBPW]
# PRG                     [BPR]                     [BPW]
# PRW                     [BPR]                    [GBPW]
# PWB          [GRWBPR, RGWBPR]        [GPWRBPW, RPWGBPW]
# PWG                     [BPR]                     [BPW]
# PWR                    [GBPR]                     [BPW]
# RBG                  [PRWBPR]                   [WRBPW]
# RBP            [GWBPR, WGBPR]                       [W]
# RBW                  [PRGBPR]                   [GRBPW]
# RGB                      [PR]                      [PW]
# RGP                  [WRGBPR]                   [WRBPW]
# RGW                     [BPR]                  [PRGBPW]
# RPB          [GRWBPR, WRGBPR]  [GWRBPW, WGRBPW, WRGBPW]
# RPG                    [WBPR]                   [WRBPW]
# RPW                    [GBPR]                    [GBPW]
# RWB                      [PR]          [PGRBPW, PRGBPW]
# RWG                     [BPR]                     [BPW]
# RWP                  [GRWBPR]                   [GRBPW]
# WBG                   [RWBPR]                  [PWRBPW]
# WBP                       [R]            [GRBPW, RGBPW]
# WBR                   [GWBPR]                  [PWGBPW]
# WGB                      [PR]                      [PW]
# WGP                   [RWBPR]                  [RWGBPW]
# WGR                  [PWGBPR]                     [BPW]
# WPB  [GRWBPR, RGWBPR, RWGBPR]          [GWRBPW, RWGBPW]
# WPG                   [RWBPR]                    [RBPW]
# WPR                    [GBPR]                    [GBPW]
# WRB          [PGWBPR, PWGBPR]                      [PW]
# WRG                     [BPR]                     [BPW]
# WRP                   [GWBPR]                  [GWRBPW]
#
#                           BRG                       BRP  \
# BGP                    [WBRG]                    [WBRP]
# BGR            [PWBRG, WPBRG]                   [PWBRP]
# BGW                    [PBRG]                  [RPGBRP]
# BPG                    [WBRG]                    [WBRP]
# BPR                   [GWBRG]            [GWBRP, WGBRP]
# BPW                  [RGPBRG]                    [GBRP]
# BRG                       NaN                    [WBRP]
# BRP                    [WBRG]                       NaN
# BRW                    [PBRG]                    [GBRP]
# BWG                    [PBRG]                  [RPWBRP]
# BWP                  [RGWBRG]                    [GBRP]
# BWR                   [GPBRG]                   [PGBRP]
# GBP                  [RGWBRG]                   [WGBRP]
# GBR            [PWBRG, WPBRG]                       [P]
# GBW                  [RGPBRG]                   [PGBRP]
# GPB                      [RG]          [RGWBRP, RWGBRP]
# GPR                  [WGPBRG]                   [WGBRP]
# GPW                     [BRG]                     [BRP]
# GRB          [PGWBRG, WGPBRG]  [PGWBRP, PWGBRP, WPGBRP]
# GRP                    [WBRG]                    [WBRP]
# GRW                    [PBRG]                   [PGBRP]
# GWB                      [RG]                      [RP]
# GWP                     [BRG]                  [RGWBRP]
# GWR                  [PGWBRG]                   [PGBRP]
# PBG                   [WPBRG]                  [RPWBRP]
# PBR                       [G]            [GWBRP, WGBRP]
# PBW                   [GPBRG]                  [RPGBRP]
# PGB          [RPWBRG, RWPBRG]                      [RP]
# PGR                   [WPBRG]                  [WPGBRP]
# PGW                     [BRG]                     [BRP]
# PRB  [GPWBRG, GWPBRG, WGPBRG]          [GPWBRP, WPGBRP]
# PRG                    [WBRG]                    [WBRP]
# PRW                   [GPBRG]                    [GBRP]
# PWB                      [RG]                      [RP]
# PWG                  [RPWBRG]                     [BRP]
# PWR                   [GPBRG]                  [GPWBRP]
# RBG            [PWBRG, WPBRG]                   [PWBRP]
# RBP                   [GWBRG]            [GWBRP, WGBRP]
# RBW                   [GPBRG]                   [PGBRP]
# RGB        [PRGWBRG, WRGPBRG]          [PWGBRP, WPGBRP]
# RGP                     [BRG]                    [WBRP]
# RGW                     [BRG]                     [BRP]
# RPB          [GWPBRG, WGPBRG]        [GRPWBRP, WRPGBRP]
# RPG                    [WBRG]                     [BRP]
# RPW                     [BRG]                     [BRP]
# RWB          [GPWBRG, PGWBRG]          [GPWBRP, PGWBRP]
# RWG                    [PBRG]                     [BRP]
# RWP                     [BRG]                    [GBRP]
# WBG                   [PWBRG]                   [PWBRP]
# WBP                   [GWBRG]                   [GWBRP]
# WBR                       [G]                       [P]
# WGB          [RPWBRG, RWPBRG]                      [RP]
# WGP                     [BRG]                  [RWGBRP]
# WGR                   [PWBRG]                   [PWBRP]
# WPB                      [RG]          [RGWBRP, RWGBRP]
# WPG                  [RWPBRG]                     [BRP]
# WPR                   [GWBRG]                   [GWBRP]
# WRB  [GPWBRG, GWPBRG, PGWBRG]  [GPWBRP, PGWBRP, PWGBRP]
# WRG                    [PBRG]                   [PWBRP]
# WRP                   [GWBRG]                    [GBRP]
#
#                           BRW                       BWG  ...  \
# BGP                  [RWGBRW]                    [RBWG]  ...
# BGR                   [WPBRW]                    [PBWG]  ...
# BGW                    [PBRW]            [PRBWG, RPBWG]  ...
# BPG                  [RWPBRW]                    [RBWG]  ...
# BPR                   [WGBRW]                  [WGPBWG]  ...
# BPW                    [GBRW]                   [GRBWG]  ...
# BRG                    [PBRW]                    [PBWG]  ...
# BRP                    [GBRW]                  [WGRBWG]  ...
# BRW                       NaN                   [GPBWG]  ...
# BWG                    [PBRW]                       NaN  ...
# BWP                    [GBRW]                    [RBWG]  ...
# BWR            [GPBRW, PGBRW]                    [PBWG]  ...
# GBP                   [WGBRW]                  [WGRBWG]  ...
# GBR                       [W]                  [WGPBWG]  ...
# GBW                   [PGBRW]            [PRBWG, RPBWG]  ...
# GPB                      [RW]                      [WG]  ...
# GPR                   [WGBRW]                     [BWG]  ...
# GPW                  [RGPBRW]                  [RGPBWG]  ...
# GRB  [PWGBRW, WGPBRW, WPGBRW]                      [WG]  ...
# GRP                   [WGBRW]                     [BWG]  ...
# GRW                    [PBRW]                  [PGRBWG]  ...
# GWB          [RGPBRW, RPGBRW]          [PGRBWG, RGPBWG]  ...
# GWP                     [BRW]                    [RBWG]  ...
# GWR                   [PGBRW]                    [PBWG]  ...
# PBG                   [WPBRW]                   [RPBWG]  ...
# PBR                       [W]                   [GPBWG]  ...
# PBW                   [GPBRW]                       [G]  ...
# PGB                      [RW]          [WPRBWG, WRPBWG]  ...
# PGR                   [WPBRW]                     [BWG]  ...
# PGW                  [RPGBRW]                   [RPBWG]  ...
# PRB  [GWPBRW, WGPBRW, WPGBRW]                      [WG]  ...
# PRG                   [WPBRW]                  [WPRBWG]  ...
# PRW                    [GBRW]                   [GPBWG]  ...
# PWB          [RGPBRW, RPGBRW]  [GPRBWG, GRPBWG, RGPBWG]  ...
# PWG                     [BRW]                    [RBWG]  ...
# PWR                   [GPBRW]                   [GPBWG]  ...
# RBG                   [WPBRW]                   [PRBWG]  ...
# RBP                   [WGBRW]                   [GRBWG]  ...
# RBW            [GPBRW, PGBRW]                       [G]  ...
# RGB          [PWGBRW, WPGBRW]          [WPRBWG, WRPBWG]  ...
# RGP                     [BRW]                     [BWG]  ...
# RGW                    [PBRW]                   [PRBWG]  ...
# RPB          [GWPBRW, WGPBRW]                      [WG]  ...
# RPG                     [BRW]                  [WRPBWG]  ...
# RPW                    [GBRW]                   [GRBWG]  ...
# RWB        [GRWPBRW, PRWGBRW]  [GPRBWG, GRPBWG, PGRBWG]  ...
# RWG                     [BRW]                    [PBWG]  ...
# RWP                     [BRW]                   [GRBWG]  ...
# WBG                  [RWPBRW]            [PRBWG, RPBWG]  ...
# WBP                  [RWGBRW]                   [GRBWG]  ...
# WBR            [GPBRW, PGBRW]                   [GPBWG]  ...
# WGB                      [RW]        [PWGRBWG, RWGPBWG]  ...
# WGP                     [BRW]                     [BWG]  ...
# WGR                  [PWGBRW]                     [BWG]  ...
# WPB                      [RW]          [GRPBWG, RGPBWG]  ...
# WPG                     [BRW]                    [RBWG]  ...
# WPR                  [GWPBRW]                     [BWG]  ...
# WRB          [GWPBRW, PWGBRW]          [GPRBWG, PGRBWG]  ...
# WRG                    [PBRW]                    [PBWG]  ...
# WRP                    [GBRW]                     [BWG]  ...
#
#                           WBR                       WGB  \
# BGP                     [WBR]                    [RWGB]
# BGR                    [PWBR]                    [PWGB]
# BGW          [PRGWBR, RPGWBR]          [PBRWGB, RBPWGB]
# BPG                     [WBR]                  [RBPWGB]
# BPR                    [GWBR]                     [WGB]
# BPW          [GRPWBR, RGPWBR]                      [GB]
# BRG                     [WBR]                  [PBRWGB]
# BRP                     [WBR]                     [WGB]
# BRW        [GBRPWBR, PBRGWBR]                      [GB]
# BWG                   [RPWBR]            [PRWGB, RPWGB]
# BWP                   [RGWBR]                  [GBRWGB]
# BWR            [GPWBR, PGWBR]                  [GBPWGB]
# GBP                   [RGWBR]                     [WGB]
# GBR                    [PWBR]                     [WGB]
# GBW  [PRGWBR, RGPWBR, RPGWBR]        [PGBRWGB, RGBPWGB]
# GPB                   [RGWBR]                    [RWGB]
# GPR                  [BGPWBR]                     [WGB]
# GPW                      [BR]          [BRPWGB, RBPWGB]
# GRB                   [PGWBR]                    [PWGB]
# GRP                     [WBR]                     [WGB]
# GRW          [BGPWBR, BPGWBR]          [BPRWGB, PBRWGB]
# GWB                       [R]            [PRWGB, RPWGB]
# GWP                   [RGWBR]                   [BRWGB]
# GWR                   [PGWBR]                   [BPWGB]
# PBG                   [RPWBR]                   [RPWGB]
# PBR                    [GWBR]                     [WGB]
# PBW  [GRPWBR, RGPWBR, RPGWBR]          [GPRWGB, GRPWGB]
# PGB                   [RPWBR]                    [RWGB]
# PGR                  [BPGWBR]                   [BPWGB]
# PGW                      [BR]  [BPRWGB, BRPWGB, RBPWGB]
# PRB                   [GPWBR]                  [GPRWGB]
# PRG                     [WBR]                   [BPWGB]
# PRW          [BGPWBR, BPGWBR]                      [GB]
# PWB                       [R]                   [RPWGB]
# PWG                   [RPWBR]                       [B]
# PWR                   [GPWBR]                   [BPWGB]
# RBG                    [PWBR]                   [PRWGB]
# RBP                    [GWBR]                     [WGB]
# RBW          [GRPWBR, PRGWBR]          [GPRWGB, GRPWGB]
# RGB                  [PRGWBR]                    [PWGB]
# RGP                     [WBR]                   [BRWGB]
# RGW                      [BR]  [BPRWGB, BRPWGB, PBRWGB]
# RPB                  [GRPWBR]                  [GRPWGB]
# RPG                     [WBR]                   [BRWGB]
# RPW                      [BR]                      [GB]
# RWB            [GPWBR, PGWBR]                   [PRWGB]
# RWG                  [BRPWBR]                       [B]
# RWP                  [BRGWBR]                   [BRWGB]
# WBG                    [PWBR]            [PRWGB, RPWGB]
# WBP                    [GWBR]                    [RWGB]
# WBR                       NaN                    [PWGB]
# WGB                   [RPWBR]                       NaN
# WGP                  [BRGWBR]                    [RWGB]
# WGR                    [PWBR]                    [PWGB]
# WPB                   [RGWBR]                    [RWGB]
# WPG                  [BRPWBR]                   [BRWGB]
# WPR                    [GWBR]                  [GBPWGB]
# WRB            [GPWBR, PGWBR]                    [PWGB]
# WRG                    [PWBR]                   [BPWGB]
# WRP                    [GWBR]                  [GBRWGB]
#
#                           WGP                       WGR  \
# BGP                    [RWGP]                   [RBWGR]
# BGR                   [PBWGP]                    [PWGR]
# BGW  [PBRWGP, PRBWGP, RPBWGP]  [PRBWGR, RBPWGR, RPBWGR]
# BPG                   [RBWGP]                   [RBWGR]
# BPR                     [WGP]                  [GBPWGR]
# BPW          [GBRWGP, GRBWGP]                      [GR]
# BRG                   [PBWGP]                   [PBWGR]
# BRP                  [GBRWGP]                     [WGR]
# BRW                      [GP]          [GBPWGR, GPBWGR]
# BWG                       [P]                       [R]
# BWP                   [RBWGP]                   [RBWGR]
# BWR                   [PBWGP]                   [PBWGR]
# GBP                    [RWGP]                     [WGR]
# GBR                     [WGP]                    [PWGR]
# GBW          [PRBWGP, RPBWGP]          [PRBWGR, RPBWGR]
# GPB                     [WGP]                     [WGR]
# GPR                     [WGP]                    [BWGR]
# GPW        [BGPRWGP, RGPBWGP]          [BRPWGR, RBPWGR]
# GRB                     [WGP]                     [WGR]
# GRP                    [BWGP]                     [WGR]
# GRW          [BPRWGP, PBRWGP]        [BGRPWGR, PGRBWGR]
# GWB                   [PRWGP]                   [RPWGR]
# GWP            [BRWGP, RBWGP]                   [RBWGR]
# GWR                   [PBWGP]            [BPWGR, PBWGR]
# PBG                  [RPBWGP]                   [RPWGR]
# PBR                     [WGP]                  [GPBWGR]
# PBW                      [GP]                      [GR]
# PGB                    [RWGP]                   [RPWGR]
# PGR                    [BWGP]                    [BWGR]
# PGW          [BPRWGP, RPBWGP]  [BRPWGR, RBPWGR, RPBWGR]
# PRB                     [WGP]                     [WGR]
# PRG                  [BPRWGP]                   [BPWGR]
# PRW                      [GP]          [GBPWGR, GPBWGR]
# PWB                  [GPRWGP]                   [RPWGR]
# PWG            [BRWGP, RBWGP]                       [R]
# PWR                  [GPBWGP]                   [BPWGR]
# RBG                   [PRWGP]                  [PRBWGR]
# RBP                  [GRBWGP]                     [WGR]
# RBW                      [GP]                      [GR]
# RGB                   [PRWGP]                    [PWGR]
# RGP                    [BWGP]                    [BWGR]
# RGW  [BPRWGP, PBRWGP, PRBWGP]          [BRPWGR, PRBWGR]
# RPB                     [WGP]                     [WGR]
# RPG                   [BRWGP]                  [BRPWGR]
# RPW          [GBRWGP, GRBWGP]                      [GR]
# RWB                   [PRWGP]                  [GRPWGR]
# RWG                       [P]            [BPWGR, PBWGR]
# RWP                   [BRWGP]                  [GRBWGR]
# WBG                   [PRWGP]                   [RPWGR]
# WBP                    [RWGP]                  [GRBWGR]
# WBR                  [GPBWGP]                    [PWGR]
# WGB                    [RWGP]                    [PWGR]
# WGP                       NaN                    [BWGR]
# WGR                    [BWGP]                       NaN
# WPB                    [RWGP]                  [GRPWGR]
# WPG            [BRWGP, RBWGP]                   [RBWGR]
# WPR                    [BWGP]                    [BWGR]
# WRB                  [GPRWGP]                    [PWGR]
# WRG                   [PBWGP]            [BPWGR, PBWGR]
# WRP                    [BWGP]                    [BWGR]
#
#                           WPB                       WPG  \
# BGP                  [RBGWPB]                   [RBWPG]
# BGR                     [WPB]                     [WPG]
# BGW                      [PB]          [PBRWPG, PRBWPG]
# BPG                    [RWPB]                    [RWPG]
# BPR                    [GWPB]                   [GBWPG]
# BPW          [GBRWPB, RBGWPB]  [GBRWPG, GRBWPG, RGBWPG]
# BRG                     [WPB]                  [PBRWPG]
# BRP                  [GBRWPB]                   [GBWPG]
# BRW                      [PB]                      [PG]
# BWG                  [PBRWPB]                   [RBWPG]
# BWP            [GRWPB, RGWPB]                       [G]
# BWR                  [PBGWPB]                   [GBWPG]
# GBP                   [RGWPB]                  [RGBWPG]
# GBR                     [WPB]                     [WPG]
# GBW          [PGRWPB, PRGWPB]                      [PG]
# GPB                    [RWPB]                    [RWPG]
# GPR                   [BGWPB]                    [BWPG]
# GPW  [BGRWPB, BRGWPB, RBGWPB]          [BGRWPG, RGBWPG]
# GRB                  [PGRWPB]                     [WPG]
# GRP                   [BGWPB]                  [BGRWPG]
# GRW                      [PB]                      [PG]
# GWB                   [RGWPB]                  [PGRWPG]
# GWP                       [B]            [BRWPG, RBWPG]
# GWR                   [BGWPB]                  [PGBWPG]
# PBG                     [WPB]                    [RWPG]
# PBR                     [WPB]                     [WPG]
# PBW        [GPBRWPB, RPBGWPB]          [GRBWPG, RGBWPG]
# PGB                    [RWPB]                     [WPG]
# PGR                     [WPB]                     [WPG]
# PGW          [BRGWPB, RBGWPB]        [BPGRWPG, RPGBWPG]
# PRB                    [GWPB]                     [WPG]
# PRG                     [WPB]                    [BWPG]
# PRW          [BGRWPB, GBRWPB]          [BGRWPG, GBRWPG]
# PWB            [GRWPB, RGWPB]                   [GRWPG]
# PWG                   [BRWPB]            [BRWPG, RBWPG]
# PWR                   [BGWPB]                   [GBWPG]
# RBG                     [WPB]                  [PRBWPG]
# RBP                   [GRWPB]                   [GRWPG]
# RBW          [PGRWPB, PRGWPB]                      [PG]
# RGB                  [PRGWPB]                     [WPG]
# RGP                   [BRWPB]                   [BRWPG]
# RGW                      [PB]          [PBRWPG, PRBWPG]
# RPB                    [GWPB]                   [GRWPG]
# RPG                   [BRWPB]                    [BWPG]
# RPW  [BGRWPB, BRGWPB, GBRWPB]  [BGRWPG, GBRWPG, GRBWPG]
# RWB                   [GRWPB]                   [GRWPG]
# RWG                   [BRWPB]                   [BRWPG]
# RWP                       [B]                       [G]
# WBG                    [RWPB]                    [RWPG]
# WBP            [GRWPB, RGWPB]                   [GRWPG]
# WBR                    [GWPB]                  [PGBWPG]
# WGB                    [RWPB]                    [RWPG]
# WGP                   [BRWPB]            [BRWPG, RBWPG]
# WGR                  [PBGWPB]                    [BWPG]
# WPB                       NaN                    [RWPG]
# WPG                    [RWPB]                       NaN
# WPR                    [GWPB]                    [BWPG]
# WRB                    [GWPB]                  [PGRWPG]
# WRG                  [PBRWPB]                    [BWPG]
# WRP                   [BGWPB]                   [GBWPG]
#
#                           WPR                       WRB  \
# BGP                   [RBWPR]                     [WRB]
# BGR                  [PBGWPR]                  [PBGWRB]
# BGW                      [PR]                      [RB]
# BPG                   [RBWPR]                     [WRB]
# BPR                    [GWPR]                  [GBPWRB]
# BPW  [GRBWPR, RBGWPR, RGBWPR]                      [RB]
# BRG                     [WPR]                    [PWRB]
# BRP                   [GBWPR]                    [GWRB]
# BRW          [PBGWPR, PGBWPR]          [GBPWRB, PBGWRB]
# BWG                   [RBWPR]                  [RBPWRB]
# BWP                       [R]                  [RBGWRB]
# BWR                   [GBWPR]            [GPWRB, PGWRB]
# GBP                   [RGWPR]                     [WRB]
# GBR                  [PGBWPR]                   [PGWRB]
# GBW                      [PR]          [RGPWRB, RPGWRB]
# GPB                   [RGWPR]                  [RGPWRB]
# GPR                    [BWPR]                   [BGWRB]
# GPW  [BRGWPR, RBGWPR, RGBWPR]                      [RB]
# GRB                     [WPR]                    [PWRB]
# GRP                   [BGWPR]                   [BGWRB]
# GRW          [PBGWPR, PGBWPR]  [BGPWRB, BPGWRB, PBGWRB]
# GWB                   [RGWPR]                   [PGWRB]
# GWP                       [R]                   [BGWRB]
# GWR                   [BGWPR]                       [B]
# PBG                     [WPR]                     [WRB]
# PBR                    [GWPR]                   [GPWRB]
# PBW          [GRBWPR, RGBWPR]          [RGPWRB, RPGWRB]
# PGB                     [WPR]                  [RPGWRB]
# PGR                    [BWPR]                   [BPWRB]
# PGW          [BRGWPR, RBGWPR]                      [RB]
# PRB                     [WPR]                    [GWRB]
# PRG                     [WPR]                   [BPWRB]
# PRW        [BPRGWPR, GPRBWPR]  [BGPWRB, BPGWRB, GBPWRB]
# PWB                   [RGWPR]                   [GPWRB]
# PWG                   [RBWPR]                   [BPWRB]
# PWR            [BGWPR, GBWPR]                       [B]
# RBG                     [WPR]                     [WRB]
# RBP                  [GRBWPR]                     [WRB]
# RBW                      [PR]        [GRBPWRB, PRBGWRB]
# RGB                     [WPR]                    [PWRB]
# RGP                  [BRGWPR]                     [WRB]
# RGW                      [PR]          [BPGWRB, PBGWRB]
# RPB                    [GWPR]                    [GWRB]
# RPG                    [BWPR]                     [WRB]
# RPW          [BRGWPR, GRBWPR]          [BGPWRB, GBPWRB]
# RWB                  [PRGWPR]            [GPWRB, PGWRB]
# RWG                  [PRBWPR]                   [BPWRB]
# RWP            [BGWPR, GBWPR]                   [BGWRB]
# WBG                  [PRBWPR]                    [PWRB]
# WBP                   [RGWPR]                    [GWRB]
# WBR                    [GWPR]            [GPWRB, PGWRB]
# WGB                  [PRGWPR]                    [PWRB]
# WGP                   [RBWPR]                  [RBGWRB]
# WGR                    [BWPR]                   [BPWRB]
# WPB                    [GWPR]                    [GWRB]
# WPG                    [BWPR]                  [RBPWRB]
# WPR                       NaN                   [BGWRB]
# WRB                    [GWPR]                       NaN
# WRG                    [BWPR]                    [PWRB]
# WRP            [BGWPR, GBWPR]                    [GWRB]
#
#                           WRG                       WRP
# BGP                     [WRG]                  [RBGWRP]
# BGR                   [PBWRG]                   [PBWRP]
# BGW          [RBPWRG, RPBWRG]                      [RP]
# BPG                  [RBPWRG]                     [WRP]
# BPR                   [GBWRG]                   [GBWRP]
# BPW                      [RG]          [RBGWRP, RGBWRP]
# BRG                    [PWRG]                   [PBWRP]
# BRP                   [GBWRG]                    [GWRP]
# BRW  [GBPWRG, GPBWRG, PGBWRG]  [GPBWRP, PBGWRP, PGBWRP]
# BWG                   [PBWRG]                   [PBWRP]
# BWP                   [GBWRG]                   [GBWRP]
# BWR                       [G]                       [P]
# GBP                     [WRG]                  [RGBWRP]
# GBR                  [PGBWRG]                   [PGWRP]
# GBW                      [RG]                      [RP]
# GPB                     [WRG]                     [WRP]
# GPR                  [BGPWRG]                   [BGWRP]
# GPW                      [RG]          [RBGWRP, RGBWRP]
# GRB                    [PWRG]                   [PGWRP]
# GRP                    [BWRG]                    [BWRP]
# GRW          [BGPWRG, PGBWRG]  [BPGWRP, PBGWRP, PGBWRP]
# GWB                  [RGPWRG]                   [PGWRP]
# GWP                  [RGBWRG]                   [BGWRP]
# GWR            [BPWRG, PBWRG]                       [P]
# PBG                  [RPBWRG]                     [WRP]
# PBR                   [GPWRG]                  [GPBWRP]
# PBW                      [RG]                      [RP]
# PGB                     [WRG]                     [WRP]
# PGR                   [BPWRG]                  [BPGWRP]
# PGW          [RBPWRG, RPBWRG]                      [RP]
# PRB                   [GPWRG]                    [GWRP]
# PRG                    [BWRG]                    [BWRP]
# PRW  [BGPWRG, GBPWRG, GPBWRG]          [BPGWRP, GPBWRP]
# PWB                   [GPWRG]                  [RPGWRP]
# PWG                   [BPWRG]                  [RPBWRP]
# PWR                       [G]            [BGWRP, GBWRP]
# RBG                    [PWRG]                     [WRP]
# RBP                     [WRG]                    [GWRP]
# RBW          [GPBWRG, PGBWRG]          [GPBWRP, PGBWRP]
# RGB                     [WRG]                     [WRP]
# RGP                     [WRG]                    [BWRP]
# RGW        [BRGPWRG, PRGBWRG]          [BPGWRP, PBGWRP]
# RPB                     [WRG]                     [WRP]
# RPG                    [BWRG]                     [WRP]
# RPW          [BGPWRG, GBPWRG]        [BRPGWRP, GRPBWRP]
# RWB                   [GPWRG]                   [PGWRP]
# RWG            [BPWRG, PBWRG]                   [PBWRP]
# RWP                   [GBWRG]            [BGWRP, GBWRP]
# WBG                    [PWRG]                  [RPBWRP]
# WBP                  [RGBWRG]                    [GWRP]
# WBR                   [GPWRG]                   [PGWRP]
# WGB                    [PWRG]                  [RPGWRP]
# WGP                    [BWRG]                    [BWRP]
# WGR            [BPWRG, PBWRG]                   [PBWRP]
# WPB                  [RGPWRG]                    [GWRP]
# WPG                    [BWRG]                    [BWRP]
# WPR                   [GBWRG]            [BGWRP, GBWRP]
# WRB                    [PWRG]                    [GWRP]
# WRG                       NaN                    [BWRP]
# WRP                    [BWRG]                       NaN
#
# [60 rows x 84 columns]
